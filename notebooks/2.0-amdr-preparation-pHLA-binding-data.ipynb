# %% [markdown]
# # Prepare pHLA binding data
#
# In this notebook we will prepare the pHLA binding data for the training and test sets.
# We will process peptide sequences with their correspongind HLA allele and label.
# ## Load useful functions

# %%
import os
import glob
import numpy as np
import pandas as pd
from typing import Tuple
from sklearn.preprocessing import MinMaxScaler

# %%
def is_valid_peptide(peptide: str) -> bool:
    """
    Check if the peptide has valid characters
    :param peptide: str
        Peptide to check
    :return: bool
        True if peptide is valid, False otherwise
    """
    peptide = peptide.upper()
    valid_aa = 'ACDEFGHIKLMNPQRSTVWY'
    return all([aa in valid_aa for aa in peptide])

def filter_peptides_by_len(peptides_list: list,
                           min_len: int = 8, 
                           max_len: int = 12) -> Tuple[list, list]:
    """
    Get list of peptides that have min_len or more AA and
    less or fewer max_len AA (min_len <= len(peptide) <= max_len)
    :param peptides_list: list
        List of peptides (as str) to filter
    :param min_len: int
        Minimum length of peptides to keep
    :param max_len: int
        Maximum length of peptides to keep
    :return: Tuple[list, list]
        * List of peptides that have min_len or more AA and
        less or fewer max_len AA
        * List of indices of the peptides in the original list
        that passed the filter
    """
    # Filter epitopes to 8 to 12 AA
    filt_peptides = []
    index_mask = []
    n_invalid = 0
    for i, p in enumerate(peptides_list):
        if max_len >= len(p) >= min_len and is_valid_peptide(p):
            filt_peptides.append(p)
            index_mask.append(i)
        else:
            n_invalid +=1
    print(f'\t {n_invalid} peptides out of {len(seqs_epi_raw)} were not betweem {min_len} and {max_len} AA.')
    return filt_peptides, index_mask

def scale_peptide_encodings(peptide_encodings: np.ndarray) -> np.ndarray:
    """
    Scale each feature (col) of the peptide encodings to be between 0 and 1
    :param peptide_encodings: np.ndarray
        Encodings to scale
    :return: np.ndarray
        Scaled encodings
    """
    scaler = MinMaxScaler()
    return scaler.fit_transform(peptide_encodings)

# %% [markdown]
# # Globals

# %%
DATA_FOLDER = os.path.join('..', 'data')
RAW_DATA_FOLDER = os.path.join(DATA_FOLDER, 'raw')
RAW_pHLA_BINDING_DATA_FOLDER = os.path.join(RAW_DATA_FOLDER, 'pHLA_binding')
INTERIM_DATA_FOLDER = os.path.join(DATA_FOLDER, 'interim')
INTERIM_pHLA_BINDING_DATA_FOLDER = os.path.join(INTERIM_DATA_FOLDER, 'pHLA_binding')
PROCESS_DATA_FOLDER = os.path.join(DATA_FOLDER, 'processed')
PROCESS_pHLA_BINDING_DATA_FOLDER = os.path.join(PROCESS_DATA_FOLDER, 'pHLA_binding')

# %% [markdown]
# ## Process NetMHCpan data
#
# We will generate the train and test sets using the paper original split.
#
# ### Warnings
#
# - Only the binding affinity trainig set data is upload to the repository. The EL and test data are too large. Therefore, the used will need to executed it locally!

# %%
netmhcpan_raw_train_folder = os.path.join(RAW_pHLA_BINDING_DATA_FOLDER, 'NetMHCpan_train')
alleles_list_file = os.path.join(netmhcpan_raw_train_folder, 'allelelist')
netmhcpan_raw_test_folder = os.path.join(RAW_pHLA_BINDING_DATA_FOLDER, 'CD8_benchmark_filtered')
netmhcpan_interim_folder = os.path.join(INTERIM_pHLA_BINDING_DATA_FOLDER, 'NetMHCpan_dataset')

# %%
# binding affinity data
ba_files = glob.glob(f'{netmhcpan_raw_train_folder}/*_ba')
# eluted ligand data
el_files = glob.glob(f'{netmhcpan_raw_train_folder}/*el')
# Test set files
test_files = glob.glob(f'{netmhcpan_raw_test_folder}/*HLA*')

# Make dict with allelelist data for Multi-allelic data
with open(alleles_list_file, 'r') as f:
    alleles_dict = {}
    for line in f:
        line = line.strip()
        if line:
            line = line.replace(':', '-')
            allele, hla_list = line.split()
            hla_list = hla_list.split(',')
            alleles_dict[allele] = hla_list

# %% [markdown]
# ## Process NetMHCpan data
#
# We will generate a dataframe with the following columns:
# - `peptide`: the peptide/epitope amino acid sequence
# - `is_mono_allelic`: whether the epitope is presented by a single HLA allele (True, False)
# - `hla_allele`: the HLA allele or alleles that the epitope binds (name format: HLA-A01-01)
# - `label`: Whether the peptide binds to the HLA allele (1: Binder, 0: Non-binder)
#
# ### Warnings
# - We won't apply the filter for the peptide length, as we are not going to encode the peptides.
# - Only HLA with allele A, B or C will be kept.
# - HLA-alleles names Normalized to HLA-A01-01 format

# %%
MAX_PEPTIDE_LEN = 15 # Usually epitopes are between 8 to 14 aminoacids, but we set to 15 to be sure


netmhcpan_raw_train_folder = os.path.join(RAW_pHLA_BINDING_DATA_FOLDER, 'NetMHCpan_train')
alleles_list_file = os.path.join(netmhcpan_raw_train_folder, 'allelelist')
netmhcpan_raw_test_folder = os.path.join(RAW_pHLA_BINDING_DATA_FOLDER, 'CD8_benchmark_filtered')
netmhcpan_process_folder = os.path.join(PROCESS_pHLA_BINDING_DATA_FOLDER, 'NetMHCpan_dataset')

# %%
# binding affinity data
ba_files = glob.glob(f'{netmhcpan_raw_train_folder}/*_ba')
# eluted ligand data
el_files = glob.glob(f'{netmhcpan_raw_train_folder}/*el')
# Test set files
test_files = glob.glob(f'{netmhcpan_raw_test_folder}/*HLA*')

# Make dict with allelelist data for Multi-allelic data
with open(alleles_list_file, 'r') as f:
    alleles_dict = {}
    for line in f:
        line = line.strip()
        if line:
            line = line.replace(':', '-')
            allele, hla_list = line.split()
            hla_list = hla_list.split(',')
            alleles_dict[allele] = hla_list

# %%
# Process Binding Affinity data
ba_seq_pep_list = [] # List of peptide sequences for all files
ba_epi_labels_list = [] # List of epitope labels for all files
ba_hla_list = [] # List of HLA alleles per epitope for all files
ba_is_multi_allelic = [] # List of whether the epitope is presented by multiple alleles

for f in ba_files:
    print(f'Processing {f}')
    df = pd.read_csv(f, sep=' ', header=None, names=('epitope', 'binding_affinity', 'hla_allele'))
    df = df[df['hla_allele'].str.startswith('HLA')] # Only consider HLAs
    # Normalize HLA naming to HLA-A01-01 format
    df['hla_allele'] = df['hla_allele'].str.replace(':', '-')
    # Filter the HLA alleles to only keep A, B or C
    df = df[df['hla_allele'].str[4].isin(['A', 'B', 'C'])]
    seqs_epi_raw = df['epitope'].values.tolist()
    valid_epi, valid_epi_idx = filter_peptides_by_len(seqs_epi_raw, max_len=MAX_PEPTIDE_LEN)
    
    df = df.iloc[valid_epi_idx] # Filter out invalid epitopes
    binding_labels = df['binding_affinity'] >= 0.426 # Above is considered a binder
    binding_labels_arr = binding_labels.to_numpy().astype(int)
    
    # Get array of HLAs
    hla_array = df['hla_allele'].values
    
    ba_seq_pep_list.append(df['epitope'].values)
    ba_epi_labels_list.append(binding_labels_arr)
    ba_hla_list.append(hla_array)
    ba_is_multi_allelic.append(np.zeros(binding_labels_arr.shape[0], dtype=bool))
    
all_seq_pep = np.concatenate(ba_seq_pep_list)
all_ba_epi_labels = np.concatenate(ba_epi_labels_list)
all_ba_hla = np.concatenate(ba_hla_list)
all_ba_is_multi_allelic = np.concatenate(ba_is_multi_allelic)

assert (all_ba_epi_labels.shape[0] == all_ba_hla.shape[0]
        == all_ba_is_multi_allelic.shape[0]), 'Mismatch in data shapes.'

binding_affinity_df = pd.DataFrame({
    'peptide': all_seq_pep,
    'is_mono_allelic': ~all_ba_is_multi_allelic,
    'hla_allele': all_ba_hla,
    'label': all_ba_epi_labels,
})

binding_affinity_df.to_csv(os.path.join(netmhcpan_process_folder, 'train_binding_affinity_peptides_data_MaxLenPep15_hla_ABC.csv'), index=False)
# Out:
# Processing ../data/raw/pHLA_binding/NetMHCpan_train/c003_ba
# 	 0 peptides out of 33789 were not betweem 8 and 15 AA.
# Processing ../data/raw/pHLA_binding/NetMHCpan_train/c002_ba
# 	 0 peptides out of 33897 were not betweem 8 and 15 AA.
# Processing ../data/raw/pHLA_binding/NetMHCpan_train/c000_ba
# 	 0 peptides out of 33446 were not betweem 8 and 15 AA.
# Processing ../data/raw/pHLA_binding/NetMHCpan_train/c004_ba
# 	 0 peptides out of 34527 were not betweem 8 and 15 AA.
# Processing ../data/raw/pHLA_binding/NetMHCpan_train/c001_ba
# 	 0 peptides out of 34448 were not betweem 8 and 15 AA.

# %%
binding_affinity_df.peptide.str.len().value_counts()
# Out:
# peptide
# 9     126375
# 10     31939
# 8       5562
# 11      5391
# 13       387
# 12       233
# 14       220
# Name: count, dtype: int64

# %%
# Process Eluted Ligand data

el_seq_pep_list = [] # List of peptide sequences for all files
el_epi_labels_list = [] # List of epitope labels for all files
el_hla_list = [] # List of HLA alleles per epitope for all files
el_is_multi_allelic = [] # List of whether the epitope is presented by multiple alleles

for f in el_files:
    print(f'Processing {f}')
    df = pd.read_csv(f, sep=' ', header=None, names=('epitope', 'eluted_ligand', 'mhc_codes'))
    mhc_codes_in_file = df['mhc_codes'].values
    mhc_equivalences = [alleles_dict.get(mhc, [mhc]) for mhc in mhc_codes_in_file]
    # Check if each equivalence in mhc_equivalences are HLAs
    has_hla = [all([e.startswith('HLA') for e in equivalences]) for equivalences in mhc_equivalences]
    is_multi_allelic = [len(equivalences) > 1 for equivalences in mhc_equivalences]
    df['is_multi_allelic'] = is_multi_allelic
    df['hla_allele'] = mhc_equivalences
    df = df[has_hla] # Only consider HLAs
    
    # DEBUG
    # df = df[:1000]
    
    seqs_epi_raw = df['epitope'].values.tolist()
    valid_epi, valid_epi_idx = filter_peptides_by_len(seqs_epi_raw, max_len=MAX_PEPTIDE_LEN)
    
    df = df.iloc[valid_epi_idx] # Filter out invalid epitopes
    el_labels = df['eluted_ligand'] == 1 
    el_labels_arr = el_labels.to_numpy().astype(int)
    
    # Normalize HLA naming
    hla_array = df['hla_allele'].values
    
    el_seq_pep_list.append(df['epitope'].values)
    el_epi_labels_list.append(el_labels_arr)
    el_hla_list.append(hla_array)
    el_is_multi_allelic.append(df['is_multi_allelic'].values)
    
    
all_seq_pep = np.concatenate(el_seq_pep_list)
all_el_epi_labels = np.concatenate(el_epi_labels_list)
all_el_hla = np.concatenate(el_hla_list)
all_el_is_multi_allelic = np.concatenate(el_is_multi_allelic)

assert (all_el_epi_labels.shape[0] == all_el_hla.shape[0] == 
        all_el_is_multi_allelic.shape[0]), 'Mismatch in data shapes.'

eluted_ligand_df = pd.DataFrame({
    'peptide': all_seq_pep,
    'is_mono_allelic': ~all_el_is_multi_allelic,
    'hla_allele': all_el_hla,
    'label': all_el_epi_labels,
})

# Separate between multialelic and monoalelic data in EL data
eluted_ligand_df_mono = eluted_ligand_df[~all_el_is_multi_allelic]
eluted_ligand_df_multi = eluted_ligand_df[all_el_is_multi_allelic]
# Change hla_allele to string for monoalelic data
eluted_ligand_df_mono['hla_allele'] = eluted_ligand_df_mono['hla_allele'].apply(lambda x: x[0])
# Filter Monoallelic data to only keep HLA-A, B or C
eluted_ligand_df_mono = eluted_ligand_df_mono[eluted_ligand_df_mono['hla_allele'].str[4].isin(['A', 'B', 'C'])]
# Filter Multiallelic data to only keep instances with all HLAs as HLA-A, B or C
eluted_ligand_df_multi = eluted_ligand_df_multi[eluted_ligand_df_multi['hla_allele'].apply(lambda x: all([hla[4] in ['A', 'B', 'C'] for hla in x]))]

eluted_ligand_df_mono.to_csv(os.path.join(netmhcpan_process_folder, 'train_eluted_ligand_peptides_data_mono_MaxLenPep15_hla_ABC.csv.gz'), index=False)
eluted_ligand_df_multi.to_pickle(os.path.join(netmhcpan_process_folder, 'train_eluted_ligand_peptides_data_multi_MaxLenPep15_hla_ABC.pkl'))
# Out:
# Processing ../data/raw/pHLA_binding/NetMHCpan_train/c003_el
# 	 4 peptides out of 2139289 were not betweem 8 and 15 AA.
# Processing ../data/raw/pHLA_binding/NetMHCpan_train/c001_el
# 	 1 peptides out of 2128029 were not betweem 8 and 15 AA.
# Processing ../data/raw/pHLA_binding/NetMHCpan_train/c000_el
# 	 0 peptides out of 2135167 were not betweem 8 and 15 AA.
# Processing ../data/raw/pHLA_binding/NetMHCpan_train/c002_el
# 	 0 peptides out of 2137018 were not betweem 8 and 15 AA.
# Processing ../data/raw/pHLA_binding/NetMHCpan_train/c004_el
# 	 0 peptides out of 2130923 were not betweem 8 and 15 AA.
# /tmp/ipykernel_26604/1001539165.py:58: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   eluted_ligand_df_mono['hla_allele'] = eluted_ligand_df_mono['hla_allele'].apply(lambda x: x[0])

# %%
eluted_ligand_df_mono.peptide.str.len().value_counts()
# Out:
# peptide
# 9     633595
# 10    566243
# 11    552255
# 8     542317
# 12    481920
# 13    467900
# 14    422991
# 15     12180
# Name: count, dtype: int64

# %%
eluted_ligand_df_multi.peptide.str.len().value_counts()
# Out:
# peptide
# 9     1294911
# 10    1145518
# 11    1123207
# 8     1094057
# 12     781594
# 13     777007
# 14     774726
# Name: count, dtype: int64

# %%
# Process Test set data 

test_seq_pep_list = [] # List of peptide sequences for all files
test_epi_labels_list = [] # List of epitope labels for all files
test_hla_list = [] # List of HLA alleles per epitope for all files
test_is_multi_allelic = [] # List of whether the epitope is presented by multiple alleles

for f in test_files:
    print(f'Processing {f}')
    df = pd.read_csv(f, sep=' ', header=None, names=('epitope', 'binding_label', 'hla_allele'))
    df = df[df['hla_allele'].str.startswith('HLA')] # Only consider HLAs
    # Normalize HLA naming to HLA-A01-01 format
    df['hla_allele'] = df['hla_allele'].str.replace(':', '-')
    # Filter the HLA alleles to only keep A, B or C
    df = df[df['hla_allele'].str[4].isin(['A', 'B', 'C'])]
    
    seqs_epi_raw = df['epitope'].values.tolist()
    valid_epi, valid_epi_idx = filter_peptides_by_len(seqs_epi_raw, max_len=MAX_PEPTIDE_LEN)
    
    df = df.iloc[valid_epi_idx] # Filter out invalid epitopes
    binding_labels = df['binding_label'] == 1 
    binding_labels_arr = binding_labels.to_numpy().astype(int)
    
    # HLA to array
    hla_array = df['hla_allele'].values
    
    test_seq_pep_list.append(df['epitope'].values)
    test_epi_labels_list.append(binding_labels_arr)
    test_hla_list.append(hla_array)
    test_is_multi_allelic.append(np.zeros(binding_labels_arr.shape[0], dtype=bool))
    
all_seq_pep = np.concatenate(test_seq_pep_list)
all_test_epi_labels = np.concatenate(test_epi_labels_list)
all_test_hla = np.concatenate(test_hla_list)
all_test_is_multi_allelic = np.concatenate(test_is_multi_allelic)

assert (all_test_epi_labels.shape[0] == all_test_hla.shape[0] ==
        all_test_is_multi_allelic.shape[0]), 'Mismatch in data shapes.'

test_set_df = pd.DataFrame({
    'peptide': all_seq_pep,
    'is_mono_allelic': ~all_test_is_multi_allelic,
    'hla_allele': all_test_hla,
    'label': all_test_epi_labels,
})

test_set_df.to_csv(os.path.join(netmhcpan_process_folder, 'test_set_peptides_data_MaxLenPep15_hla_ABC.csv.gz'), index=False)
# Out:
# Processing ../data/raw/pHLA_binding/CD8_benchmark_filtered/SLCKLNNVFY_HLA-A03:01
# 	 0 peptides out of 1092 were not betweem 8 and 15 AA.
# Processing ../data/raw/pHLA_binding/CD8_benchmark_filtered/LAMPFATPM_HLA-B35:01
# 	 0 peptides out of 1190 were not betweem 8 and 15 AA.
# Processing ../data/raw/pHLA_binding/CD8_benchmark_filtered/IVSPFIPLL_HLA-A02:01
# 	 0 peptides out of 2730 were not betweem 8 and 15 AA.
# Processing ../data/raw/pHLA_binding/CD8_benchmark_filtered/IETVPVKL_HLA-B40:01
# 	 0 peptides out of 9975 were not betweem 8 and 15 AA.
# Processing ../data/raw/pHLA_binding/CD8_benchmark_filtered/FLFTFFASI_HLA-A02:01
# 	 0 peptides out of 2128 were not betweem 8 and 15 AA.
# Processing ../data/raw/pHLA_binding/CD8_benchmark_filtered/GMPPHMLPVL_HLA-A02:01
# 	 0 peptides out of 5075 were not betweem 8 and 15 AA.
# Processing ../data/raw/pHLA_binding/CD8_benchmark_filtered/LLGRDSFEV_HLA-A02:01
# 	 0 peptides out of 2660 were not betweem 8 and 15 AA.
# Processing ../data/raw/pHLA_binding/CD8_benchmark_filtered/YPFHDIEPS_HLA-B35:01
# 	 0 peptides out of 2331 were not betweem 8 and 15 AA.
# Processing ../data/raw/pHLA_binding/CD8_benchmark_filtered/DYSPSCCTL_HLA-A24:02
# 	 0 peptides out of 3346 were not betweem 8 and 15 AA.
# Processing ../data/raw/pHLA_binding/CD8_benchmark_filtered/ALPDIIVFSK_HLA-A11:01
# 	 0 peptides out of 784 were not betweem 8 and 15 AA.
# Processing ../data/raw/pHLA_binding/CD8_benchmark_filtered/TYTSGEACL_HLA-A24:02
# 	 0 peptides out of 2758 were not betweem 8 and 15 AA.
# Processing ../data/raw/pHLA_binding/CD8_benchmark_filtered/TNDQSFNDY_HLA-A01:01
# 	 0 peptides out of 6594 were not betweem 8 and 15 AA.
# Processing ../data/raw/pHLA_binding/CD8_benchmark_filtered/FWAKHMWNF_HLA-A24:02
# 	 0 peptides out of 21000 were not betweem 8 and 15 AA.
# Processing ../data/raw/pHLA_binding/CD8_benchmark_filtered/FMLLTQARL_HLA-A02:01
# 	 0 peptides out of 3304 were not betweem 8 and 15 AA.
# Processing ../data/raw/pHLA_binding/CD8_benchmark_filtered/ELRAREEAY_HLA-B15:02
# 	 0 peptides out of 2800 were not betweem 8 and 15 AA.
# Processing ../data/raw/pHLA_binding/CD8_benchmark_filtered/AITTILAAV_HLA-A02:01
# 	 0 peptides out of 3948 were not betweem 8 and 15 AA.
# Processing ../data/raw/pHLA_binding/CD8_benchmark_filtered/SIDCYLLAI_HLA-A02:01
# 	 0 peptides out of 2128 were not betweem 8 and 15 AA.
# Processing ../data/raw/pHLA_binding/CD8_benchmark_filtered/NLNESLIDL_HLA-A02:01
# 	 0 peptides out of 8715 were not betweem 8 and 15 AA.
# Processing ../data/raw/pHLA_binding/CD8_benchmark_filtered/YLLPRRGPRL_HLA-A31:01
# 	 0 peptides out of 21000 were not betweem 8 and 15 AA.
# Processing ../data/raw/pHLA_binding/CD8_benchmark_filtered/ALIDCNPCTL_HLA-A02:01
# 	 0 peptides out of 9359 were not betweem 8 and 15 AA.
# Processing ../data/raw/pHLA_binding/CD8_benchmark_filtered/IVLLFPSIIY_HLA-A11:01
# 	 0 peptides out of 469 were not betweem 8 and 15 AA.
# Processing ../data/raw/pHLA_binding/CD8_benchmark_filtered/SEEWERCQSF_HLA-B18:01
# 	 0 peptides out of 1708 were not betweem 8 and 15 AA.
# Processing ../data/raw/pHLA_binding/CD8_benchmark_filtered/MLNIPSINV_HLA-A02:01
# 	 0 peptides out of 3857 were not betweem 8 and 15 AA.
# Processing ../data/raw/pHLA_binding/CD8_benchmark_filtered/VIYQYMDDL_HLA-A02:01
# 	 0 peptides out of 9975 were not betweem 8 and 15 AA.
# Processing ../data/raw/pHLA_binding/CD8_benchmark_filtered/YLAGASLIY_HLA-A01:01
# 	 0 peptides out of 23891 were not betweem 8 and 15 AA.
# Processing ../data/raw/pHLA_binding/CD8_benchmark_filtered/AQSVAVEEAK_HLA-A11:01
# 	 0 peptides out of 476 were not betweem 8 and 15 AA.
# Processing ../data/raw/pHLA_binding/CD8_benchmark_filtered/NSKRTPMGF_HLA-B57:01
# 	 0 peptides out of 2877 were not betweem 8 and 15 AA.
# Processing ../data/raw/pHLA_binding/CD8_benchmark_filtered/LLLDRLNQL_HLA-A02:01
# 	 0 peptides out of 2884 were not betweem 8 and 15 AA.
# Processing ../data/raw/pHLA_binding/CD8_benchmark_filtered/KSRGKGYNW_HLA-B58:01
# 	 0 peptides out of 4284 were not betweem 8 and 15 AA.
# Processing ../data/raw/pHLA_binding/CD8_benchmark_filtered/KTWGKNLVF_HLA-B57:01
# 	 0 peptides out of 23807 were not betweem 8 and 15 AA.
# Processing ../data/raw/pHLA_binding/CD8_benchmark_filtered/TYFNLGNKF_HLA-A24:02
# 	 0 peptides out of 518 were not betweem 8 and 15 AA.
# Processing ../data/raw/pHLA_binding/CD8_benchmark_filtered/QTVTSTPVQGR_HLA-A68:01
# 	 0 peptides out of 7266 were not betweem 8 and 15 AA.
# Processing ../data/raw/pHLA_binding/CD8_benchmark_filtered/KLPDDFMGCV_HLA-A02:01
# 	 0 peptides out of 8715 were not betweem 8 and 15 AA.
# Processing ../data/raw/pHLA_binding/CD8_benchmark_filtered/TYFSLNNKF_HLA-A24:02_1
# 	 0 peptides out of 6706 were not betweem 8 and 15 AA.
# Processing ../data/raw/pHLA_binding/CD8_benchmark_filtered/EARRRLAEM_HLA-B08:01
# 	 0 peptides out of 2632 were not betweem 8 and 15 AA.
# Processing ../data/raw/pHLA_binding/CD8_benchmark_filtered/GTSGSPIVNR_HLA-A11:01_1
# 	 0 peptides out of 23674 were not betweem 8 and 15 AA.
# Processing ../data/raw/pHLA_binding/CD8_benchmark_filtered/KMYAFTLESV_HLA-A02:01
# 	 0 peptides out of 2513 were not betweem 8 and 15 AA.
# Processing ../data/raw/pHLA_binding/CD8_benchmark_filtered/DFKSKYLTL_HLA-B08:01
# 	 0 peptides out of 10570 were not betweem 8 and 15 AA.
# Processing ../data/raw/pHLA_binding/CD8_benchmark_filtered/VPGWSRRTL_HLA-B07:02
# 	 0 peptides out of 5355 were not betweem 8 and 15 AA.
# Processing ../data/raw/pHLA_binding/CD8_benchmark_filtered/NIRQAGVQY_HLA-B15:02
# 	 0 peptides out of 630 were not betweem 8 and 15 AA.
# Processing ../data/raw/pHLA_binding/CD8_benchmark_filtered/YAQMWSLMY_HLA-B53:01
# 	 0 peptides out of 23667 were not betweem 8 and 15 AA.
# Processing ../data/raw/pHLA_binding/CD8_benchmark_filtered/SVNNVCHMY_HLA-A11:01
# 	 0 peptides out of 714 were not betweem 8 and 15 AA.
# Processing ../data/raw/pHLA_binding/CD8_benchmark_filtered/IMSGEVPSM_HLA-A02:01
# 	 0 peptides out of 1526 were not betweem 8 and 15 AA.
# Processing ../data/raw/pHLA_binding/CD8_benchmark_filtered/SLYNTVAIF_HLA-A02:01
# 	 0 peptides out of 434 were not betweem 8 and 15 AA.
# Processing ../data/raw/pHLA_binding/CD8_benchmark_filtered/RVLLDILAGY_HLA-A26:01
# 	 0 peptides out of 20461 were not betweem 8 and 15 AA.
# Processing ../data/raw/pHLA_binding/CD8_benchmark_filtered/NVTSIHSLL_HLA-A68:02
# 	 0 peptides out of 595 were not betweem 8 and 15 AA.
# Processing ../data/raw/pHLA_binding/CD8_benchmark_filtered/AVYGTDLAWVL_HLA-C03:03
# 	 0 peptides out of 4165 were not betweem 8 and 15 AA.
# Processing ../data/raw/pHLA_binding/CD8_benchmark_filtered/SHLVEALYLV_HLA-A02:01
# 	 0 peptides out of 700 were not betweem 8 and 15 AA.
# Processing ../data/raw/pHLA_binding/CD8_benchmark_filtered/FLDPASIAA_HLA-A02:01
# 	 0 peptides out of 23807 were not betweem 8 and 15 AA.
# Processing ../data/raw/pHLA_binding/CD8_benchmark_filtered/LLAVSGVYPM_HLA-B15:01
# 	 0 peptides out of 23674 were not betweem 8 and 15 AA.
# Processing ../data/raw/pHLA_binding/CD8_benchmark_filtered/FLNSLAIHEK_HLA-A11:01
# 	 0 peptides out of 2891 were not betweem 8 and 15 AA.
# Processing ../data/raw/pHLA_binding/CD8_benchmark_filtered/TLVAHGPSL_HLA-A02:01
# 	 0 peptides out of 3514 were not betweem 8 and 15 AA.
# Processing ../data/raw/pHLA_binding/CD8_benchmark_filtered/GLRYRSMLL_HLA-A02:02
# 	 0 peptides out of 6594 were not betweem 8 and 15 AA.
# Processing ../data/raw/pHLA_binding/CD8_benchmark_filtered/RANELMRAMK_HLA-B07:02
# 	 0 peptides out of 5075 were not betweem 8 and 15 AA.
# Processing ../data/raw/pHLA_binding/CD8_benchmark_filtered/CLLESVYTA_HLA-A02:01
# 	 0 peptides out of 1960 were not betweem 8 and 15 AA.
# Processing ../data/raw/pHLA_binding/CD8_benchmark_filtered/ADLMGYIPLV_HLA-A02:01
# 	 0 peptides out of 21007 were not betweem 8 and 15 AA.
# Processing ../data/raw/pHLA_binding/CD8_benchmark_filtered/VLFAAFSSA_HLA-A02:01
# 	 0 peptides out of 14875 were not betweem 8 and 15 AA.
# Processing ../data/raw/pHLA_binding/CD8_benchmark_filtered/KLAKPLPYT_HLA-A02:01
# 	 0 peptides out of 3815 were not betweem 8 and 15 AA.
# Processing ../data/raw/pHLA_binding/CD8_benchmark_filtered/KLVFELSA_HLA-A02:01
# 	 0 peptides out of 4284 were not betweem 8 and 15 AA.
# Processing ../data/raw/pHLA_binding/CD8_benchmark_filtered/YIVRWEWVV_HLA-A02:01
# 	 0 peptides out of 21168 were not betweem 8 and 15 AA.
# Processing ../data/raw/pHLA_binding/CD8_benchmark_filtered/SYAAAQRKLL_HLA-A24:02
# 	 0 peptides out of 3409 were not betweem 8 and 15 AA.
# Processing ../data/raw/pHLA_binding/CD8_benchmark_filtered/ALWGPDPAA_HLA-A02:01
# 	 0 peptides out of 700 were not betweem 8 and 15 AA.
# Processing ../data/raw/pHLA_binding/CD8_benchmark_filtered/MMARDTAEA_HLA-A02:01
# 	 0 peptides out of 602 were not betweem 8 and 15 AA.
# Processing ../data/raw/pHLA_binding/CD8_benchmark_filtered/GQISIQPTFS_HLA-B15:01
# 	 0 peptides out of 3416 were not betweem 8 and 15 AA.
# Processing ../data/raw/pHLA_binding/CD8_benchmark_filtered/ATFAEIGHK_HLA-A11:01
# 	 0 peptides out of 966 were not betweem 8 and 15 AA.
# Processing ../data/raw/pHLA_binding/CD8_benchmark_filtered/DMSNLFDWL_HLA-A02:01
# 	 0 peptides out of 1897 were not betweem 8 and 15 AA.
# Processing ../data/raw/pHLA_binding/CD8_benchmark_filtered/FVFPTKDVALR_HLA-A68:01_1
# 	 0 peptides out of 3857 were not betweem 8 and 15 AA.
# Processing ../data/raw/pHLA_binding/CD8_benchmark_filtered/ALWALPHAA_HLA-A02:01
# 	 0 peptides out of 9100 were not betweem 8 and 15 AA.
# Processing ../data/raw/pHLA_binding/CD8_benchmark_filtered/ALAVLSVTL_HLA-A02:01
# 	 0 peptides out of 6461 were not betweem 8 and 15 AA.
# Processing ../data/raw/pHLA_binding/CD8_benchmark_filtered/SLLQGSPHL_HLA-A02:01
# 	 0 peptides out of 1799 were not betweem 8 and 15 AA.
# Processing ../data/raw/pHLA_binding/CD8_benchmark_filtered/ELNNALQNL_HLA-A24:02
# 	 0 peptides out of 595 were not betweem 8 and 15 AA.
# Processing ../data/raw/pHLA_binding/CD8_benchmark_filtered/LLMRTTWAF_HLA-A02:01
# 	 0 peptides out of 23639 were not betweem 8 and 15 AA.
# Processing ../data/raw/pHLA_binding/CD8_benchmark_filtered/VPRPDDPVL_HLA-B07:02
# 	 0 peptides out of 3675 were not betweem 8 and 15 AA.
# Processing ../data/raw/pHLA_binding/CD8_benchmark_filtered/ANTMAMMAR_HLA-A11:01
# 	 0 peptides out of 602 were not betweem 8 and 15 AA.
# Processing ../data/raw/pHLA_binding/CD8_benchmark_filtered/FYTPLADQF_HLA-A24:02_1
# 	 0 peptides out of 4627 were not betweem 8 and 15 AA.
# Processing ../data/raw/pHLA_binding/CD8_benchmark_filtered/ALATVTLKY_HLA-A29:02
# 	 0 peptides out of 4781 were not betweem 8 and 15 AA.
# Processing ../data/raw/pHLA_binding/CD8_benchmark_filtered/VQAVTNAGK_HLA-A11:01
# 	 0 peptides out of 1274 were not betweem 8 and 15 AA.
# Processing ../data/raw/pHLA_binding/CD8_benchmark_filtered/GLAEDLAAL_HLA-A02:01
# 	 0 peptides out of 3220 were not betweem 8 and 15 AA.
# Processing ../data/raw/pHLA_binding/CD8_benchmark_filtered/HPFALLLVL_HLA-B35:03
# 	 0 peptides out of 23807 were not betweem 8 and 15 AA.
# Processing ../data/raw/pHLA_binding/CD8_benchmark_filtered/GPQRLPVPV_HLA-B07:02
# 	 0 peptides out of 23891 were not betweem 8 and 15 AA.
# Processing ../data/raw/pHLA_binding/CD8_benchmark_filtered/DLILELLDL_HLA-A02:01
# 	 0 peptides out of 13531 were not betweem 8 and 15 AA.
# Processing ../data/raw/pHLA_binding/CD8_benchmark_filtered/QLLKLNVPA_HLA-A02:01
# 	 0 peptides out of 17815 were not betweem 8 and 15 AA.
# Processing ../data/raw/pHLA_binding/CD8_benchmark_filtered/ELRRKMMYM_HLA-B08:02
# 	 0 peptides out of 3367 were not betweem 8 and 15 AA.
# Processing ../data/raw/pHLA_binding/CD8_benchmark_filtered/LPFERATVL_HLA-B35:01
# 	 0 peptides out of 3297 were not betweem 8 and 15 AA.
# Processing ../data/raw/pHLA_binding/CD8_benchmark_filtered/FIRMWNQAAL_HLA-A02:01
# 	 0 peptides out of 2366 were not betweem 8 and 15 AA.
# Processing ../data/raw/pHLA_binding/CD8_benchmark_filtered/SPRLCTREEF_HLA-B07:02
# 	 0 peptides out of 23639 were not betweem 8 and 15 AA.
# Processing ../data/raw/pHLA_binding/CD8_benchmark_filtered/TVINASRFK_HLA-A11:01
# 	 0 peptides out of 10360 were not betweem 8 and 15 AA.
# Processing ../data/raw/pHLA_binding/CD8_benchmark_filtered/ATDSLNNEY_HLA-A01:01
# 	 0 peptides out of 4956 were not betweem 8 and 15 AA.
# Processing ../data/raw/pHLA_binding/CD8_benchmark_filtered/AYVSVLYRW_HLA-A24:02
# 	 0 peptides out of 4956 were not betweem 8 and 15 AA.
# Processing ../data/raw/pHLA_binding/CD8_benchmark_filtered/RIKDFLRNL_HLA-C06:02
# 	 0 peptides out of 1120 were not betweem 8 and 15 AA.
# Processing ../data/raw/pHLA_binding/CD8_benchmark_filtered/LTCLNISSLR_HLA-A03:01
# 	 0 peptides out of 2184 were not betweem 8 and 15 AA.
# Processing ../data/raw/pHLA_binding/CD8_benchmark_filtered/YLFLICHNLR_HLA-A11:01
# 	 0 peptides out of 763 were not betweem 8 and 15 AA.
# Processing ../data/raw/pHLA_binding/CD8_benchmark_filtered/HPVGEADYFEY_HLA-B08:01
# 	 0 peptides out of 4417 were not betweem 8 and 15 AA.
# Processing ../data/raw/pHLA_binding/CD8_benchmark_filtered/EGRERILTV_HLA-B08:01
# 	 0 peptides out of 3290 were not betweem 8 and 15 AA.
# Processing ../data/raw/pHLA_binding/CD8_benchmark_filtered/WLNEVEFKL_HLA-A02:01_1
# 	 0 peptides out of 25725 were not betweem 8 and 15 AA.
# Processing ../data/raw/pHLA_binding/CD8_benchmark_filtered/TPRVTGGGA_HLA-B07:02
# 	 0 peptides out of 3857 were not betweem 8 and 15 AA.
# Processing ../data/raw/pHLA_binding/CD8_benchmark_filtered/LLAMKVPNV_HLA-A02:01
# 	 0 peptides out of 4879 were not betweem 8 and 15 AA.
# Processing ../data/raw/pHLA_binding/CD8_benchmark_filtered/YPLHEQHGM_HLA-B35:01
# 	 0 peptides out of 6538 were not betweem 8 and 15 AA.
# Processing ../data/raw/pHLA_binding/CD8_benchmark_filtered/YQSGLSIVM_HLA-B39:01
# 	 0 peptides out of 2205 were not betweem 8 and 15 AA.
# Processing ../data/raw/pHLA_binding/CD8_benchmark_filtered/VMNILLQYVV_HLA-A02:01
# 	 0 peptides out of 4025 were not betweem 8 and 15 AA.
# Processing ../data/raw/pHLA_binding/CD8_benchmark_filtered/KINQSLAFI_HLA-A02:01
# 	 0 peptides out of 3955 were not betweem 8 and 15 AA.
# Processing ../data/raw/pHLA_binding/CD8_benchmark_filtered/RLMDSSIYS_HLA-A02:01
# 	 0 peptides out of 4998 were not betweem 8 and 15 AA.
# Processing ../data/raw/pHLA_binding/CD8_benchmark_filtered/YVVTWIVGA_HLA-A02:01
# 	 0 peptides out of 4725 were not betweem 8 and 15 AA.
# Processing ../data/raw/pHLA_binding/CD8_benchmark_filtered/ALLPTALDAL_HLA-A02:01
# 	 0 peptides out of 17815 were not betweem 8 and 15 AA.
# Processing ../data/raw/pHLA_binding/CD8_benchmark_filtered/FLMEDQTLL_HLA-A02:01
# 	 0 peptides out of 3983 were not betweem 8 and 15 AA.
# Processing ../data/raw/pHLA_binding/CD8_benchmark_filtered/EECDSELEIKRY_HLA-B18:01
# 	 0 peptides out of 1645 were not betweem 8 and 15 AA.
# Processing ../data/raw/pHLA_binding/CD8_benchmark_filtered/ETFTETWNR_HLA-A68:01
# 	 0 peptides out of 1267 were not betweem 8 and 15 AA.
# Processing ../data/raw/pHLA_binding/CD8_benchmark_filtered/HPYRTWTY_HLA-B35:01
# 	 0 peptides out of 23961 were not betweem 8 and 15 AA.
# Processing ../data/raw/pHLA_binding/CD8_benchmark_filtered/RPTEPVPFQL_HLA-B07:02
# 	 0 peptides out of 560 were not betweem 8 and 15 AA.
# Processing ../data/raw/pHLA_binding/CD8_benchmark_filtered/IIIILIIFI_HLA-A02:06
# 	 0 peptides out of 2632 were not betweem 8 and 15 AA.
# Processing ../data/raw/pHLA_binding/CD8_benchmark_filtered/TVSSLGGCNK_HLA-A11:01
# 	 0 peptides out of 476 were not betweem 8 and 15 AA.
# Processing ../data/raw/pHLA_binding/CD8_benchmark_filtered/VAALFFFDI_HLA-A24:02
# 	 0 peptides out of 3857 were not betweem 8 and 15 AA.
# Processing ../data/raw/pHLA_binding/CD8_benchmark_filtered/YIIVFVVAL_HLA-A02:01
# 	 0 peptides out of 3038 were not betweem 8 and 15 AA.
# Processing ../data/raw/pHLA_binding/CD8_benchmark_filtered/ILMWEAVTV_HLA-A02:01
# 	 0 peptides out of 2478 were not betweem 8 and 15 AA.
# Processing ../data/raw/pHLA_binding/CD8_benchmark_filtered/KLLAGDEIV_HLA-A02:01
# 	 0 peptides out of 11242 were not betweem 8 and 15 AA.
# Processing ../data/raw/pHLA_binding/CD8_benchmark_filtered/IPVMRKAYL_HLA-B07:02
# 	 0 peptides out of 4746 were not betweem 8 and 15 AA.
# Processing ../data/raw/pHLA_binding/CD8_benchmark_filtered/LYLVCGERGF_HLA-A24:02
# 	 0 peptides out of 700 were not betweem 8 and 15 AA.
# Processing ../data/raw/pHLA_binding/CD8_benchmark_filtered/CYSIEPLDL_HLA-A24:02_1
# 	 0 peptides out of 21007 were not betweem 8 and 15 AA.
# Processing ../data/raw/pHLA_binding/CD8_benchmark_filtered/AYRHAMEEL_HLA-A24:02
# 	 0 peptides out of 23674 were not betweem 8 and 15 AA.
# Processing ../data/raw/pHLA_binding/CD8_benchmark_filtered/AVLCLYLLY_HLA-A29:02
# 	 0 peptides out of 3990 were not betweem 8 and 15 AA.
# Processing ../data/raw/pHLA_binding/CD8_benchmark_filtered/MEIFIEVFSHF_HLA-B44:02
# 	 0 peptides out of 301 were not betweem 8 and 15 AA.
# Processing ../data/raw/pHLA_binding/CD8_benchmark_filtered/LPFERATIM_HLA-B35:01
# 	 0 peptides out of 3381 were not betweem 8 and 15 AA.
# Processing ../data/raw/pHLA_binding/CD8_benchmark_filtered/LQTHIFAEV_HLA-A02:06
# 	 0 peptides out of 4417 were not betweem 8 and 15 AA.
# Processing ../data/raw/pHLA_binding/CD8_benchmark_filtered/RRLVVTLQC_HLA-B27:05
# 	 0 peptides out of 1120 were not betweem 8 and 15 AA.
# Processing ../data/raw/pHLA_binding/CD8_benchmark_filtered/VELGSGNSF_HLA-B37:01
# 	 0 peptides out of 2912 were not betweem 8 and 15 AA.
# Processing ../data/raw/pHLA_binding/CD8_benchmark_filtered/LPLNVGLPIIGVM_HLA-B35:01
# 	 0 peptides out of 1113 were not betweem 8 and 15 AA.
# Processing ../data/raw/pHLA_binding/CD8_benchmark_filtered/LLDFVRFMGV_HLA-A02:01
# 	 0 peptides out of 6874 were not betweem 8 and 15 AA.
# Processing ../data/raw/pHLA_binding/CD8_benchmark_filtered/KLQVFLIVL_HLA-A02:01
# 	 0 peptides out of 553 were not betweem 8 and 15 AA.
# Processing ../data/raw/pHLA_binding/CD8_benchmark_filtered/TMSSSHLFYL_HLA-A02:01
# 	 0 peptides out of 1295 were not betweem 8 and 15 AA.
# Processing ../data/raw/pHLA_binding/CD8_benchmark_filtered/YPKMYHICFF_HLA-B51:01
# 	 0 peptides out of 3038 were not betweem 8 and 15 AA.
# Processing ../data/raw/pHLA_binding/CD8_benchmark_filtered/TVYPPSSTAK_HLA-A03:01
# 	 0 peptides out of 7273 were not betweem 8 and 15 AA.
# Processing ../data/raw/pHLA_binding/CD8_benchmark_filtered/YVAGFLALY_HLA-A29:02
# 	 0 peptides out of 4375 were not betweem 8 and 15 AA.
# Processing ../data/raw/pHLA_binding/CD8_benchmark_filtered/KLSDYEGRL_HLA-A02:01
# 	 0 peptides out of 3395 were not betweem 8 and 15 AA.
# Processing ../data/raw/pHLA_binding/CD8_benchmark_filtered/VLGPLVALI_HLA-A02:01
# 	 0 peptides out of 1491 were not betweem 8 and 15 AA.
# Processing ../data/raw/pHLA_binding/CD8_benchmark_filtered/LQTGIHVRV_HLA-A02:01
# 	 0 peptides out of 3787 were not betweem 8 and 15 AA.
# Processing ../data/raw/pHLA_binding/CD8_benchmark_filtered/KLSHQPVLL_HLA-A02:01
# 	 0 peptides out of 1113 were not betweem 8 and 15 AA.
# Processing ../data/raw/pHLA_binding/CD8_benchmark_filtered/GVEGEGLHK_HLA-A11:01
# 	 0 peptides out of 23674 were not betweem 8 and 15 AA.
# Processing ../data/raw/pHLA_binding/CD8_benchmark_filtered/SSNIMSESY_HLA-A01:01
# 	 0 peptides out of 4389 were not betweem 8 and 15 AA.
# Processing ../data/raw/pHLA_binding/CD8_benchmark_filtered/RPKVEGLEY_HLA-B35:01
# 	 0 peptides out of 1659 were not betweem 8 and 15 AA.
# Processing ../data/raw/pHLA_binding/CD8_benchmark_filtered/VLIAGYIIVFV_HLA-A02:01
# 	 0 peptides out of 3038 were not betweem 8 and 15 AA.
# Processing ../data/raw/pHLA_binding/CD8_benchmark_filtered/SPGSGFWSF_HLA-B07:02
# 	 0 peptides out of 4025 were not betweem 8 and 15 AA.
# Processing ../data/raw/pHLA_binding/CD8_benchmark_filtered/YMWLGARY_HLA-A01:01
# 	 0 peptides out of 23807 were not betweem 8 and 15 AA.
# Processing ../data/raw/pHLA_binding/CD8_benchmark_filtered/VLTSKVLDL_HLA-A02:01
# 	 0 peptides out of 3948 were not betweem 8 and 15 AA.
# Processing ../data/raw/pHLA_binding/CD8_benchmark_filtered/IMPGQEAGL_HLA-A02:01
# 	 0 peptides out of 4655 were not betweem 8 and 15 AA.
# Processing ../data/raw/pHLA_binding/CD8_benchmark_filtered/QTTPYNFIAK_HLA-A11:01
# 	 0 peptides out of 1043 were not betweem 8 and 15 AA.
# Processing ../data/raw/pHLA_binding/CD8_benchmark_filtered/IPYLDGTFY_HLA-B53:01
# 	 0 peptides out of 6594 were not betweem 8 and 15 AA.
# Processing ../data/raw/pHLA_binding/CD8_benchmark_filtered/APVIKARMM_HLA-B07:02
# 	 0 peptides out of 4025 were not betweem 8 and 15 AA.
# Processing ../data/raw/pHLA_binding/CD8_benchmark_filtered/QLDEQNSVL_HLA-A02:01
# 	 0 peptides out of 3752 were not betweem 8 and 15 AA.
# Processing ../data/raw/pHLA_binding/CD8_benchmark_filtered/VPWQPAFVF_HLA-B35:01
# 	 0 peptides out of 1141 were not betweem 8 and 15 AA.
# Processing ../data/raw/pHLA_binding/CD8_benchmark_filtered/DVILPIGTR_HLA-A68:01
# 	 0 peptides out of 23807 were not betweem 8 and 15 AA.
# Processing ../data/raw/pHLA_binding/CD8_benchmark_filtered/SLQNSEFLL_HLA-A02:01
# 	 0 peptides out of 4795 were not betweem 8 and 15 AA.
# Processing ../data/raw/pHLA_binding/CD8_benchmark_filtered/RFIAQLLLL_HLA-A02:01
# 	 0 peptides out of 1477 were not betweem 8 and 15 AA.
# Processing ../data/raw/pHLA_binding/CD8_benchmark_filtered/CTELKLNDY_HLA-A01:01
# 	 0 peptides out of 3416 were not betweem 8 and 15 AA.
# Processing ../data/raw/pHLA_binding/CD8_benchmark_filtered/CRVLCCYVL_HLA-C07:02_1
# 	 0 peptides out of 3367 were not betweem 8 and 15 AA.
# Processing ../data/raw/pHLA_binding/CD8_benchmark_filtered/RQYDPVAAL_HLA-B07:02_1
# 	 0 peptides out of 3857 were not betweem 8 and 15 AA.
# Processing ../data/raw/pHLA_binding/CD8_benchmark_filtered/APLCLMVLAYL_HLA-B51:01
# 	 0 peptides out of 3038 were not betweem 8 and 15 AA.
# Processing ../data/raw/pHLA_binding/CD8_benchmark_filtered/TPRVTGGGAM_HLA-B07:02_1
# 	 0 peptides out of 3857 were not betweem 8 and 15 AA.
# Processing ../data/raw/pHLA_binding/CD8_benchmark_filtered/VPRTDNITL_HLA-B07:02
# 	 0 peptides out of 23891 were not betweem 8 and 15 AA.
# Processing ../data/raw/pHLA_binding/CD8_benchmark_filtered/FPQLSAIAL_HLA-B35:01
# 	 0 peptides out of 5103 were not betweem 8 and 15 AA.
# Processing ../data/raw/pHLA_binding/CD8_benchmark_filtered/TLEEFSAKL_HLA-A02:01
# 	 0 peptides out of 567 were not betweem 8 and 15 AA.
# Processing ../data/raw/pHLA_binding/CD8_benchmark_filtered/MLQEKPFQL_HLA-A02:01
# 	 0 peptides out of 4144 were not betweem 8 and 15 AA.
# Processing ../data/raw/pHLA_binding/CD8_benchmark_filtered/LVYANSAANPI_HLA-B51:01
# 	 0 peptides out of 3038 were not betweem 8 and 15 AA.
# Processing ../data/raw/pHLA_binding/CD8_benchmark_filtered/ASCMGLIY_HLA-B35:01
# 	 0 peptides out of 1694 were not betweem 8 and 15 AA.
# Processing ../data/raw/pHLA_binding/CD8_benchmark_filtered/TLKKYFIPV_HLA-A02:01
# 	 0 peptides out of 17815 were not betweem 8 and 15 AA.
# Processing ../data/raw/pHLA_binding/CD8_benchmark_filtered/CPRRPAVAF_HLA-B07:02
# 	 0 peptides out of 2660 were not betweem 8 and 15 AA.
# Processing ../data/raw/pHLA_binding/CD8_benchmark_filtered/HISALKRRY_HLA-A01:01
# 	 0 peptides out of 1078 were not betweem 8 and 15 AA.
# Processing ../data/raw/pHLA_binding/CD8_benchmark_filtered/NYLDLSALL_HLA-A24:02
# 	 0 peptides out of 5131 were not betweem 8 and 15 AA.
# Processing ../data/raw/pHLA_binding/CD8_benchmark_filtered/YLLKPVQRI_HLA-A02:01
# 	 0 peptides out of 6405 were not betweem 8 and 15 AA.
# Processing ../data/raw/pHLA_binding/CD8_benchmark_filtered/KLLEILAEHV_HLA-A02:01
# 	 0 peptides out of 6783 were not betweem 8 and 15 AA.
# Processing ../data/raw/pHLA_binding/CD8_benchmark_filtered/DATYQRTRALVR_HLA-A68:01_1
# 	 0 peptides out of 3416 were not betweem 8 and 15 AA.
# Processing ../data/raw/pHLA_binding/CD8_benchmark_filtered/YICEEASVTV_HLA-A02:01
# 	 0 peptides out of 2485 were not betweem 8 and 15 AA.
# Processing ../data/raw/pHLA_binding/CD8_benchmark_filtered/MYNYPAMLG_HLA-A24:02
# 	 0 peptides out of 602 were not betweem 8 and 15 AA.
# Processing ../data/raw/pHLA_binding/CD8_benchmark_filtered/GIIYIIYKL_HLA-A02:01
# 	 0 peptides out of 15225 were not betweem 8 and 15 AA.
# Processing ../data/raw/pHLA_binding/CD8_benchmark_filtered/FEKERFLFL_HLA-B08:01
# 	 0 peptides out of 2023 were not betweem 8 and 15 AA.
# Processing ../data/raw/pHLA_binding/CD8_benchmark_filtered/AMPPELNTA_HLA-A02:01
# 	 0 peptides out of 2366 were not betweem 8 and 15 AA.
# Processing ../data/raw/pHLA_binding/CD8_benchmark_filtered/AYQGDYKLF_HLA-A23:01
# 	 0 peptides out of 5103 were not betweem 8 and 15 AA.
# Processing ../data/raw/pHLA_binding/CD8_benchmark_filtered/LLFGYPVYV_HLA-A02:06_1
# 	 0 peptides out of 2401 were not betweem 8 and 15 AA.
# Processing ../data/raw/pHLA_binding/CD8_benchmark_filtered/QIMYNYPAM_HLA-A11:01
# 	 0 peptides out of 602 were not betweem 8 and 15 AA.
# Processing ../data/raw/pHLA_binding/CD8_benchmark_filtered/LASDPHYEY_HLA-A29:02
# 	 0 peptides out of 4956 were not betweem 8 and 15 AA.
# Processing ../data/raw/pHLA_binding/CD8_benchmark_filtered/AEDLNLGNL_HLA-B40:01
# 	 0 peptides out of 5831 were not betweem 8 and 15 AA.
# Processing ../data/raw/pHLA_binding/CD8_benchmark_filtered/STLPETTVI_HLA-A02:01
# 	 0 peptides out of 1414 were not betweem 8 and 15 AA.
# Processing ../data/raw/pHLA_binding/CD8_benchmark_filtered/SLLNSLIVCR_HLA-A11:01
# 	 0 peptides out of 385 were not betweem 8 and 15 AA.
# Processing ../data/raw/pHLA_binding/CD8_benchmark_filtered/VLEWRFDSRL_HLA-A02:01
# 	 0 peptides out of 1372 were not betweem 8 and 15 AA.
# Processing ../data/raw/pHLA_binding/CD8_benchmark_filtered/LLLLLPPRV_HLA-A02:01
# 	 0 peptides out of 7035 were not betweem 8 and 15 AA.
# Processing ../data/raw/pHLA_binding/CD8_benchmark_filtered/ALYEKKLAL_HLA-A02:01
# 	 0 peptides out of 23807 were not betweem 8 and 15 AA.
# Processing ../data/raw/pHLA_binding/CD8_benchmark_filtered/FMDILTTCVET_HLA-A02:01
# 	 0 peptides out of 3367 were not betweem 8 and 15 AA.
# Processing ../data/raw/pHLA_binding/CD8_benchmark_filtered/RQYDPVAAL_HLA-B15:01
# 	 0 peptides out of 3857 were not betweem 8 and 15 AA.
# Processing ../data/raw/pHLA_binding/CD8_benchmark_filtered/QPSLILVSQY_HLA-B35:01
# 	 0 peptides out of 3857 were not betweem 8 and 15 AA.
# Processing ../data/raw/pHLA_binding/CD8_benchmark_filtered/LLMEGVPKSL_HLA-A02:01
# 	 0 peptides out of 2513 were not betweem 8 and 15 AA.
# Processing ../data/raw/pHLA_binding/CD8_benchmark_filtered/TDLGQNLLY_HLA-A01:01
# 	 0 peptides out of 6594 were not betweem 8 and 15 AA.
# Processing ../data/raw/pHLA_binding/CD8_benchmark_filtered/RGINDRNFW_HLA-B57:01
# 	 0 peptides out of 3416 were not betweem 8 and 15 AA.
# Processing ../data/raw/pHLA_binding/CD8_benchmark_filtered/AYLPRPVEF_HLA-A24:02
# 	 0 peptides out of 7791 were not betweem 8 and 15 AA.
# Processing ../data/raw/pHLA_binding/CD8_benchmark_filtered/KPYSGTAYNAL_HLA-B07:02
# 	 0 peptides out of 6706 were not betweem 8 and 15 AA.
# Processing ../data/raw/pHLA_binding/CD8_benchmark_filtered/FLTEAIVHSV_HLA-A02:01
# 	 0 peptides out of 15085 were not betweem 8 and 15 AA.
# Processing ../data/raw/pHLA_binding/CD8_benchmark_filtered/SSADVEFCL_HLA-A02:01
# 	 0 peptides out of 3633 were not betweem 8 and 15 AA.
# Processing ../data/raw/pHLA_binding/CD8_benchmark_filtered/TLQPVERVL_HLA-A02:01
# 	 0 peptides out of 4690 were not betweem 8 and 15 AA.
# Processing ../data/raw/pHLA_binding/CD8_benchmark_filtered/VIIVILLSL_HLA-A02:01
# 	 0 peptides out of 3955 were not betweem 8 and 15 AA.
# Processing ../data/raw/pHLA_binding/CD8_benchmark_filtered/FPSIIYSMSI_HLA-B07:02
# 	 0 peptides out of 469 were not betweem 8 and 15 AA.
# Processing ../data/raw/pHLA_binding/CD8_benchmark_filtered/FLYALALL_HLA-A02:01
# 	 0 peptides out of 3409 were not betweem 8 and 15 AA.
# Processing ../data/raw/pHLA_binding/CD8_benchmark_filtered/VPFMRTDML_HLA-B07:02
# 	 0 peptides out of 637 were not betweem 8 and 15 AA.
# Processing ../data/raw/pHLA_binding/CD8_benchmark_filtered/ALYDVVTKL_HLA-A02:01
# 	 0 peptides out of 21007 were not betweem 8 and 15 AA.
# Processing ../data/raw/pHLA_binding/CD8_benchmark_filtered/HERNGFTVL_HLA-B40:02
# 	 0 peptides out of 3857 were not betweem 8 and 15 AA.
# Processing ../data/raw/pHLA_binding/CD8_benchmark_filtered/LLVHFLPLL_HLA-A02:01
# 	 0 peptides out of 686 were not betweem 8 and 15 AA.
# Processing ../data/raw/pHLA_binding/CD8_benchmark_filtered/VFWAKHMWNF_HLA-A24:02
# 	 0 peptides out of 21000 were not betweem 8 and 15 AA.
# Processing ../data/raw/pHLA_binding/CD8_benchmark_filtered/KCDDVLLLL_HLA-A02:01
# 	 0 peptides out of 4914 were not betweem 8 and 15 AA.
# Processing ../data/raw/pHLA_binding/CD8_benchmark_filtered/VRMILLTHF_HLA-B27:05
# 	 0 peptides out of 21007 were not betweem 8 and 15 AA.
# Processing ../data/raw/pHLA_binding/CD8_benchmark_filtered/ALIPYCVHM_HLA-A02:01
# 	 0 peptides out of 2415 were not betweem 8 and 15 AA.
# Processing ../data/raw/pHLA_binding/CD8_benchmark_filtered/ILIVMVPFL_HLA-A02:01
# 	 0 peptides out of 2128 were not betweem 8 and 15 AA.
# Processing ../data/raw/pHLA_binding/CD8_benchmark_filtered/MGSLEMVPM_HLA-B35:01
# 	 0 peptides out of 3409 were not betweem 8 and 15 AA.
# Processing ../data/raw/pHLA_binding/CD8_benchmark_filtered/GFLIAYQPLL_HLA-A02:01_1
# 	 0 peptides out of 6258 were not betweem 8 and 15 AA.
# Processing ../data/raw/pHLA_binding/CD8_benchmark_filtered/RAEAQLHAW_HLA-B57:01
# 	 0 peptides out of 4494 were not betweem 8 and 15 AA.
# Processing ../data/raw/pHLA_binding/CD8_benchmark_filtered/ALDAQAVEL_HLA-A02:01
# 	 0 peptides out of 2366 were not betweem 8 and 15 AA.
# Processing ../data/raw/pHLA_binding/CD8_benchmark_filtered/MTTEDMLQVW_HLA-B58:01_1
# 	 0 peptides out of 23961 were not betweem 8 and 15 AA.
# Processing ../data/raw/pHLA_binding/CD8_benchmark_filtered/YKSHGKGYNW_HLA-B58:01
# 	 0 peptides out of 4102 were not betweem 8 and 15 AA.
# Processing ../data/raw/pHLA_binding/CD8_benchmark_filtered/AYHPQQFIY_HLA-C07:02
# 	 0 peptides out of 2205 were not betweem 8 and 15 AA.
# Processing ../data/raw/pHLA_binding/CD8_benchmark_filtered/MLAAQMFIV_HLA-A02:01
# 	 0 peptides out of 21161 were not betweem 8 and 15 AA.
# Processing ../data/raw/pHLA_binding/CD8_benchmark_filtered/FEHVDLSEEL_HLA-B37:01
# 	 0 peptides out of 1470 were not betweem 8 and 15 AA.
# Processing ../data/raw/pHLA_binding/CD8_benchmark_filtered/NEVVVKEEY_HLA-B18:01
# 	 0 peptides out of 4284 were not betweem 8 and 15 AA.
# Processing ../data/raw/pHLA_binding/CD8_benchmark_filtered/YAQMWQLLY_HLA-A01:01
# 	 0 peptides out of 23891 were not betweem 8 and 15 AA.
# Processing ../data/raw/pHLA_binding/CD8_benchmark_filtered/AEIEDLIFS_HLA-B40:02
# 	 0 peptides out of 3416 were not betweem 8 and 15 AA.
# Processing ../data/raw/pHLA_binding/CD8_benchmark_filtered/SLFLGILSV_HLA-A02:01
# 	 0 peptides out of 2009 were not betweem 8 and 15 AA.
# Processing ../data/raw/pHLA_binding/CD8_benchmark_filtered/RVLDTVEKW_HLA-B58:01
# 	 0 peptides out of 23807 were not betweem 8 and 15 AA.
# Processing ../data/raw/pHLA_binding/CD8_benchmark_filtered/KPRDDAAAL_HLA-B35:01
# 	 0 peptides out of 1694 were not betweem 8 and 15 AA.
# Processing ../data/raw/pHLA_binding/CD8_benchmark_filtered/GLANKTTLFTV_HLA-A02:01
# 	 0 peptides out of 3038 were not betweem 8 and 15 AA.
# Processing ../data/raw/pHLA_binding/CD8_benchmark_filtered/KYIAADRKI_HLA-A24:02
# 	 0 peptides out of 2926 were not betweem 8 and 15 AA.
# Processing ../data/raw/pHLA_binding/CD8_benchmark_filtered/QIKVRVDMV_HLA-B08:01
# 	 0 peptides out of 3367 were not betweem 8 and 15 AA.
# Processing ../data/raw/pHLA_binding/CD8_benchmark_filtered/QSSFYSDWY_HLA-A01:01
# 	 0 peptides out of 2205 were not betweem 8 and 15 AA.
# Processing ../data/raw/pHLA_binding/CD8_benchmark_filtered/YEKKLALYL_HLA-B40:02
# 	 0 peptides out of 23807 were not betweem 8 and 15 AA.
# Processing ../data/raw/pHLA_binding/CD8_benchmark_filtered/STLPETTVV_HLA-A02:01
# 	 0 peptides out of 1211 were not betweem 8 and 15 AA.
# Processing ../data/raw/pHLA_binding/CD8_benchmark_filtered/YLDLLFQIL_HLA-A02:01
# 	 0 peptides out of 17815 were not betweem 8 and 15 AA.
# Processing ../data/raw/pHLA_binding/CD8_benchmark_filtered/FQANTPPAV_HLA-A02:01
# 	 0 peptides out of 1708 were not betweem 8 and 15 AA.
# Processing ../data/raw/pHLA_binding/CD8_benchmark_filtered/IYVLVMLVL_HLA-A24:02
# 	 0 peptides out of 3409 were not betweem 8 and 15 AA.
# Processing ../data/raw/pHLA_binding/CD8_benchmark_filtered/MTNTLHSMLK_HLA-A11:01
# 	 0 peptides out of 2681 were not betweem 8 and 15 AA.
# Processing ../data/raw/pHLA_binding/CD8_benchmark_filtered/APYAGLIMI_HLA-B07:02_1
# 	 0 peptides out of 1708 were not betweem 8 and 15 AA.
# Processing ../data/raw/pHLA_binding/CD8_benchmark_filtered/LEKARGSTY_HLA-B15:01
# 	 0 peptides out of 6538 were not betweem 8 and 15 AA.
# Processing ../data/raw/pHLA_binding/CD8_benchmark_filtered/HSKKKCDEL_HLA-B08:01
# 	 0 peptides out of 21007 were not betweem 8 and 15 AA.
# Processing ../data/raw/pHLA_binding/CD8_benchmark_filtered/CYSIEPLDL_HLA-A24:02
# 	 0 peptides out of 21000 were not betweem 8 and 15 AA.
# Processing ../data/raw/pHLA_binding/CD8_benchmark_filtered/TIADFWQMV_HLA-A02:01
# 	 0 peptides out of 6783 were not betweem 8 and 15 AA.
# Processing ../data/raw/pHLA_binding/CD8_benchmark_filtered/GMGPLLATV_HLA-A02:01
# 	 0 peptides out of 5131 were not betweem 8 and 15 AA.
# Processing ../data/raw/pHLA_binding/CD8_benchmark_filtered/VTEQYGNLEK_HLA-A03:01
# 	 0 peptides out of 1092 were not betweem 8 and 15 AA.
# Processing ../data/raw/pHLA_binding/CD8_benchmark_filtered/TVADVRHCL_HLA-B07:02
# 	 0 peptides out of 1197 were not betweem 8 and 15 AA.
# Processing ../data/raw/pHLA_binding/CD8_benchmark_filtered/LLAILPYYV_HLA-A02:01
# 	 0 peptides out of 5936 were not betweem 8 and 15 AA.
# Processing ../data/raw/pHLA_binding/CD8_benchmark_filtered/ELDKYKNAV_HLA-A02:01
# 	 0 peptides out of 3948 were not betweem 8 and 15 AA.
# Processing ../data/raw/pHLA_binding/CD8_benchmark_filtered/LLHTDFEQV_HLA-A02:01
# 	 0 peptides out of 4627 were not betweem 8 and 15 AA.
# Processing ../data/raw/pHLA_binding/CD8_benchmark_filtered/GMVTTSTTL_HLA-A02:01
# 	 0 peptides out of 3409 were not betweem 8 and 15 AA.
# Processing ../data/raw/pHLA_binding/CD8_benchmark_filtered/LLSILCIWV_HLA-A02:01
# 	 0 peptides out of 2513 were not betweem 8 and 15 AA.
# Processing ../data/raw/pHLA_binding/CD8_benchmark_filtered/FMNKFIYEI_HLA-A02:01
# 	 0 peptides out of 4193 were not betweem 8 and 15 AA.
# Processing ../data/raw/pHLA_binding/CD8_benchmark_filtered/TVIRNPLSR_HLA-A68:01
# 	 0 peptides out of 23807 were not betweem 8 and 15 AA.
# Processing ../data/raw/pHLA_binding/CD8_benchmark_filtered/RQYDPVAAL_HLA-B15:01_1
# 	 0 peptides out of 3857 were not betweem 8 and 15 AA.
# Processing ../data/raw/pHLA_binding/CD8_benchmark_filtered/MPAMKRYSAP_HLA-B35:01
# 	 0 peptides out of 23639 were not betweem 8 and 15 AA.
# Processing ../data/raw/pHLA_binding/CD8_benchmark_filtered/RQYDPVAAL_HLA-A30:01_1
# 	 0 peptides out of 3857 were not betweem 8 and 15 AA.
# Processing ../data/raw/pHLA_binding/CD8_benchmark_filtered/FVRSSNLKF_HLA-B15:01
# 	 0 peptides out of 2205 were not betweem 8 and 15 AA.
# Processing ../data/raw/pHLA_binding/CD8_benchmark_filtered/IVYAEKIPR_HLA-A03:01
# 	 0 peptides out of 1092 were not betweem 8 and 15 AA.
# Processing ../data/raw/pHLA_binding/CD8_benchmark_filtered/SPKETWLRL_HLA-B35:01
# 	 0 peptides out of 2002 were not betweem 8 and 15 AA.
# Processing ../data/raw/pHLA_binding/CD8_benchmark_filtered/LLFALYFSA_HLA-A02:01
# 	 0 peptides out of 2548 were not betweem 8 and 15 AA.
# Processing ../data/raw/pHLA_binding/CD8_benchmark_filtered/MLLDKNIPI_HLA-A02:01_1
# 	 0 peptides out of 1400 were not betweem 8 and 15 AA.
# Processing ../data/raw/pHLA_binding/CD8_benchmark_filtered/PLAYFFKPR_HLA-A11:01
# 	 0 peptides out of 2891 were not betweem 8 and 15 AA.
# Processing ../data/raw/pHLA_binding/CD8_benchmark_filtered/LPFERSTIM_HLA-B35:01
# 	 0 peptides out of 3416 were not betweem 8 and 15 AA.
# Processing ../data/raw/pHLA_binding/CD8_benchmark_filtered/FLGEGHHRV_HLA-A02:01
# 	 0 peptides out of 4669 were not betweem 8 and 15 AA.
# Processing ../data/raw/pHLA_binding/CD8_benchmark_filtered/LLFGLALIEV_HLA-A02:01
# 	 0 peptides out of 2541 were not betweem 8 and 15 AA.
# Processing ../data/raw/pHLA_binding/CD8_benchmark_filtered/DTPVLPHETR_HLA-A68:01
# 	 0 peptides out of 3857 were not betweem 8 and 15 AA.
# Processing ../data/raw/pHLA_binding/CD8_benchmark_filtered/QLIMPGQEA_HLA-A02:01
# 	 0 peptides out of 4655 were not betweem 8 and 15 AA.
# Processing ../data/raw/pHLA_binding/CD8_benchmark_filtered/RPIDDRFGLA_HLA-B07:02
# 	 0 peptides out of 23807 were not betweem 8 and 15 AA.
# Processing ../data/raw/pHLA_binding/CD8_benchmark_filtered/YMSPHHKKL_HLA-A02:05
# 	 0 peptides out of 23807 were not betweem 8 and 15 AA.
# Processing ../data/raw/pHLA_binding/CD8_benchmark_filtered/IPVTMALWY_HLA-B35:01
# 	 0 peptides out of 23639 were not betweem 8 and 15 AA.
# Processing ../data/raw/pHLA_binding/CD8_benchmark_filtered/LAVDGVLSV_HLA-A02:01
# 	 0 peptides out of 2513 were not betweem 8 and 15 AA.
# Processing ../data/raw/pHLA_binding/CD8_benchmark_filtered/RPEADKVAAI_HLA-B07:02
# 	 0 peptides out of 23891 were not betweem 8 and 15 AA.
# Processing ../data/raw/pHLA_binding/CD8_benchmark_filtered/SEHPTFTSQY_HLA-B44:02
# 	 0 peptides out of 3857 were not betweem 8 and 15 AA.
# Processing ../data/raw/pHLA_binding/CD8_benchmark_filtered/RTFDPHFLRV_HLA-A02:01
# 	 0 peptides out of 1491 were not betweem 8 and 15 AA.
# Processing ../data/raw/pHLA_binding/CD8_benchmark_filtered/SVISNPSKYK_HLA-A11:01
# 	 0 peptides out of 399 were not betweem 8 and 15 AA.
# Processing ../data/raw/pHLA_binding/CD8_benchmark_filtered/VLENFTILLV_HLA-A02:01
# 	 0 peptides out of 2912 were not betweem 8 and 15 AA.
# Processing ../data/raw/pHLA_binding/CD8_benchmark_filtered/VYALPLKML_HLA-A24:02
# 	 0 peptides out of 3857 were not betweem 8 and 15 AA.
# Processing ../data/raw/pHLA_binding/CD8_benchmark_filtered/FLPLGACFPLL_HLA-A02:01
# 	 0 peptides out of 882 were not betweem 8 and 15 AA.
# Processing ../data/raw/pHLA_binding/CD8_benchmark_filtered/ARTDLEMQI_HLA-C06:02
# 	 0 peptides out of 3241 were not betweem 8 and 15 AA.
# Processing ../data/raw/pHLA_binding/CD8_benchmark_filtered/KMLKEMGEV_HLA-A02:01
# 	 0 peptides out of 2667 were not betweem 8 and 15 AA.
# Processing ../data/raw/pHLA_binding/CD8_benchmark_filtered/IFFFLFNIL_HLA-A24:02
# 	 0 peptides out of 23807 were not betweem 8 and 15 AA.
# Processing ../data/raw/pHLA_binding/CD8_benchmark_filtered/VTEHDTLLY_HLA-A01:01
# 	 0 peptides out of 2961 were not betweem 8 and 15 AA.
# Processing ../data/raw/pHLA_binding/CD8_benchmark_filtered/EVISVMKRR_HLA-A68:01
# 	 0 peptides out of 3367 were not betweem 8 and 15 AA.
# Processing ../data/raw/pHLA_binding/CD8_benchmark_filtered/NLMDGDLGL_HLA-A02:01
# 	 0 peptides out of 4746 were not betweem 8 and 15 AA.
# Processing ../data/raw/pHLA_binding/CD8_benchmark_filtered/ALAEGDLLA_HLA-A02:01
# 	 0 peptides out of 2835 were not betweem 8 and 15 AA.
# Processing ../data/raw/pHLA_binding/CD8_benchmark_filtered/LPFDRTTIM_HLA-B35:01
# 	 0 peptides out of 3416 were not betweem 8 and 15 AA.
# Processing ../data/raw/pHLA_binding/CD8_benchmark_filtered/AMLVLLAEI_HLA-A02:01
# 	 0 peptides out of 7833 were not betweem 8 and 15 AA.
# Processing ../data/raw/pHLA_binding/CD8_benchmark_filtered/IYHPQQFVYA_HLA-C07:02
# 	 0 peptides out of 2296 were not betweem 8 and 15 AA.
# Processing ../data/raw/pHLA_binding/CD8_benchmark_filtered/AILTVVAAT_HLA-A02:01
# 	 0 peptides out of 23667 were not betweem 8 and 15 AA.
# Processing ../data/raw/pHLA_binding/CD8_benchmark_filtered/LIIPCIHLI_HLA-A02:01
# 	 0 peptides out of 7469 were not betweem 8 and 15 AA.
# Processing ../data/raw/pHLA_binding/CD8_benchmark_filtered/KLLSSGAFSA_HLA-A02:01
# 	 0 peptides out of 9359 were not betweem 8 and 15 AA.
# Processing ../data/raw/pHLA_binding/CD8_benchmark_filtered/LLMLQPDYV_HLA-A02:01
# 	 0 peptides out of 3752 were not betweem 8 and 15 AA.
# Processing ../data/raw/pHLA_binding/CD8_benchmark_filtered/ELRAREESY_HLA-B15:02
# 	 0 peptides out of 3360 were not betweem 8 and 15 AA.
# Processing ../data/raw/pHLA_binding/CD8_benchmark_filtered/LIFLARSAL_HLA-A02:01
# 	 0 peptides out of 3395 were not betweem 8 and 15 AA.
# Processing ../data/raw/pHLA_binding/CD8_benchmark_filtered/LFAAFPSFA_HLA-A02:01
# 	 0 peptides out of 938 were not betweem 8 and 15 AA.
# Processing ../data/raw/pHLA_binding/CD8_benchmark_filtered/YTPDSTPCHR_HLA-A68:01
# 	 0 peptides out of 3857 were not betweem 8 and 15 AA.
# Processing ../data/raw/pHLA_binding/CD8_benchmark_filtered/ILGALLSIL_HLA-A02:01
# 	 0 peptides out of 2513 were not betweem 8 and 15 AA.
# Processing ../data/raw/pHLA_binding/CD8_benchmark_filtered/GPSLIGLAM_HLA-B07:02
# 	 0 peptides out of 2205 were not betweem 8 and 15 AA.
# Processing ../data/raw/pHLA_binding/CD8_benchmark_filtered/QLEQALDCEIY_HLA-A01:01
# 	 0 peptides out of 21007 were not betweem 8 and 15 AA.
# Processing ../data/raw/pHLA_binding/CD8_benchmark_filtered/HSKKKCDEM_HLA-B08:01
# 	 0 peptides out of 21077 were not betweem 8 and 15 AA.
# Processing ../data/raw/pHLA_binding/CD8_benchmark_filtered/MLFSMHGELYK_HLA-A11:01
# 	 0 peptides out of 287 were not betweem 8 and 15 AA.
# Processing ../data/raw/pHLA_binding/CD8_benchmark_filtered/LSFTTSTLK_HLA-A11:01
# 	 0 peptides out of 420 were not betweem 8 and 15 AA.
# Processing ../data/raw/pHLA_binding/CD8_benchmark_filtered/STLPETAVV_HLA-A02:01
# 	 0 peptides out of 1414 were not betweem 8 and 15 AA.
# Processing ../data/raw/pHLA_binding/CD8_benchmark_filtered/MLGHAGDMA_HLA-A02:01
# 	 0 peptides out of 602 were not betweem 8 and 15 AA.
# Processing ../data/raw/pHLA_binding/CD8_benchmark_filtered/LLRAESLPGA_HLA-A02:01
# 	 0 peptides out of 2366 were not betweem 8 and 15 AA.
# Processing ../data/raw/pHLA_binding/CD8_benchmark_filtered/ARMILLTHF_HLA-B27:05
# 	 0 peptides out of 903 were not betweem 8 and 15 AA.
# Processing ../data/raw/pHLA_binding/CD8_benchmark_filtered/MMFGFHHSV_HLA-A02:01
# 	 0 peptides out of 15519 were not betweem 8 and 15 AA.
# Processing ../data/raw/pHLA_binding/CD8_benchmark_filtered/QMAMIKLGAL_HLA-A02:01
# 	 0 peptides out of 1372 were not betweem 8 and 15 AA.
# Processing ../data/raw/pHLA_binding/CD8_benchmark_filtered/VIHASGKQM_HLA-A26:01
# 	 0 peptides out of 3857 were not betweem 8 and 15 AA.
# Processing ../data/raw/pHLA_binding/CD8_benchmark_filtered/ISDYFHNTY_HLA-A01:01
# 	 0 peptides out of 15085 were not betweem 8 and 15 AA.
# Processing ../data/raw/pHLA_binding/CD8_benchmark_filtered/LPFDRPTIM_HLA-B35:01
# 	 0 peptides out of 3416 were not betweem 8 and 15 AA.
# Processing ../data/raw/pHLA_binding/CD8_benchmark_filtered/LPFDKATIM_HLA-B35:01
# 	 0 peptides out of 3416 were not betweem 8 and 15 AA.
# Processing ../data/raw/pHLA_binding/CD8_benchmark_filtered/LLNYILKSV_HLA-A02:01
# 	 0 peptides out of 2212 were not betweem 8 and 15 AA.
# Processing ../data/raw/pHLA_binding/CD8_benchmark_filtered/RIFAELEGV_HLA-A02:01
# 	 0 peptides out of 3857 were not betweem 8 and 15 AA.
# Processing ../data/raw/pHLA_binding/CD8_benchmark_filtered/RSFTFKEGFK_HLA-A11:01
# 	 0 peptides out of 588 were not betweem 8 and 15 AA.
# Processing ../data/raw/pHLA_binding/CD8_benchmark_filtered/DAMYMALI_HLA-B51:01
# 	 0 peptides out of 23807 were not betweem 8 and 15 AA.
# Processing ../data/raw/pHLA_binding/CD8_benchmark_filtered/RPYKAAAAQL_HLA-B07:02
# 	 0 peptides out of 23891 were not betweem 8 and 15 AA.
# Processing ../data/raw/pHLA_binding/CD8_benchmark_filtered/RLARLALVL_HLA-A02:01
# 	 0 peptides out of 2870 were not betweem 8 and 15 AA.
# Processing ../data/raw/pHLA_binding/CD8_benchmark_filtered/KMVAVFYTT_HLA-A02:01
# 	 0 peptides out of 2107 were not betweem 8 and 15 AA.
# Processing ../data/raw/pHLA_binding/CD8_benchmark_filtered/HAVPFGLVSM_HLA-B35:01
# 	 0 peptides out of 23807 were not betweem 8 and 15 AA.
# Processing ../data/raw/pHLA_binding/CD8_benchmark_filtered/VMNILLQYV_HLA-A02:01
# 	 0 peptides out of 4025 were not betweem 8 and 15 AA.
# Processing ../data/raw/pHLA_binding/CD8_benchmark_filtered/KLEKIEDEL_HLA-A02:01
# 	 0 peptides out of 4130 were not betweem 8 and 15 AA.
# Processing ../data/raw/pHLA_binding/CD8_benchmark_filtered/SHDVLTVQF_HLA-B38:01
# 	 0 peptides out of 23807 were not betweem 8 and 15 AA.
# Processing ../data/raw/pHLA_binding/CD8_benchmark_filtered/TLFTIVGTV_HLA-A02:01
# 	 0 peptides out of 23016 were not betweem 8 and 15 AA.
# Processing ../data/raw/pHLA_binding/CD8_benchmark_filtered/KQRLTNLEK_HLA-A11:01
# 	 0 peptides out of 700 were not betweem 8 and 15 AA.
# Processing ../data/raw/pHLA_binding/CD8_benchmark_filtered/CEDVPSGKL_HLA-B40:01_1
# 	 0 peptides out of 3857 were not betweem 8 and 15 AA.
# Processing ../data/raw/pHLA_binding/CD8_benchmark_filtered/LIAGYIIVFV_HLA-A02:01
# 	 0 peptides out of 3038 were not betweem 8 and 15 AA.
# Processing ../data/raw/pHLA_binding/CD8_benchmark_filtered/LAMGPRPHSV_HLA-B07:02
# 	 0 peptides out of 882 were not betweem 8 and 15 AA.
# Processing ../data/raw/pHLA_binding/CD8_benchmark_filtered/KAFLTQLDEL_HLA-A02:01
# 	 0 peptides out of 3409 were not betweem 8 and 15 AA.
# Processing ../data/raw/pHLA_binding/CD8_benchmark_filtered/TVYYGVPAGR_HLA-A03:01
# 	 0 peptides out of 5943 were not betweem 8 and 15 AA.
# Processing ../data/raw/pHLA_binding/CD8_benchmark_filtered/WPAPPGARSM_HLA-B07:02
# 	 0 peptides out of 21000 were not betweem 8 and 15 AA.
# Processing ../data/raw/pHLA_binding/CD8_benchmark_filtered/IPLTEEAEL_HLA-B35:01
# 	 0 peptides out of 9975 were not betweem 8 and 15 AA.
# Processing ../data/raw/pHLA_binding/CD8_benchmark_filtered/RVIDSRRCL_HLA-B07:02
# 	 0 peptides out of 23891 were not betweem 8 and 15 AA.
# Processing ../data/raw/pHLA_binding/CD8_benchmark_filtered/ALLSTNKAV_HLA-A02:01
# 	 0 peptides out of 3948 were not betweem 8 and 15 AA.
# Processing ../data/raw/pHLA_binding/CD8_benchmark_filtered/TTSTRTWAL_HLA-B08:01
# 	 0 peptides out of 5082 were not betweem 8 and 15 AA.
# Processing ../data/raw/pHLA_binding/CD8_benchmark_filtered/LPFERATVM_HLA-B35:01
# 	 0 peptides out of 3416 were not betweem 8 and 15 AA.
# Processing ../data/raw/pHLA_binding/CD8_benchmark_filtered/LPWQSGSGGVW_HLA-B35:01
# 	 0 peptides out of 23807 were not betweem 8 and 15 AA.
# Processing ../data/raw/pHLA_binding/CD8_benchmark_filtered/FGIDLLWSV_HLA-A02:01
# 	 0 peptides out of 2415 were not betweem 8 and 15 AA.
# Processing ../data/raw/pHLA_binding/CD8_benchmark_filtered/FHERGYVKL_HLA-B38:01
# 	 0 peptides out of 23807 were not betweem 8 and 15 AA.
# Processing ../data/raw/pHLA_binding/CD8_benchmark_filtered/MEVTPSGTWL_HLA-B40:01
# 	 0 peptides out of 2884 were not betweem 8 and 15 AA.
# Processing ../data/raw/pHLA_binding/CD8_benchmark_filtered/VLDDHYKTAL_HLA-A02:01
# 	 0 peptides out of 20461 were not betweem 8 and 15 AA.
# Processing ../data/raw/pHLA_binding/CD8_benchmark_filtered/RPMFAVGILF_HLA-B35:01
# 	 0 peptides out of 23674 were not betweem 8 and 15 AA.
# Processing ../data/raw/pHLA_binding/CD8_benchmark_filtered/SADNNNSEY_HLA-A01:01
# 	 0 peptides out of 5075 were not betweem 8 and 15 AA.
# Processing ../data/raw/pHLA_binding/CD8_benchmark_filtered/RQYDPVAAL_HLA-A02:01_1
# 	 0 peptides out of 3857 were not betweem 8 and 15 AA.
# Processing ../data/raw/pHLA_binding/CD8_benchmark_filtered/VMPFSIVYIV_HLA-A02:01
# 	 0 peptides out of 2492 were not betweem 8 and 15 AA.
# Processing ../data/raw/pHLA_binding/CD8_benchmark_filtered/ILNNPKASL_HLA-A02:01
# 	 0 peptides out of 2667 were not betweem 8 and 15 AA.
# Processing ../data/raw/pHLA_binding/CD8_benchmark_filtered/APRTWCRLL_HLA-B07:02
# 	 0 peptides out of 2870 were not betweem 8 and 15 AA.
# Processing ../data/raw/pHLA_binding/CD8_benchmark_filtered/LPEIVREAI_HLA-B07:02
# 	 0 peptides out of 23891 were not betweem 8 and 15 AA.
# Processing ../data/raw/pHLA_binding/CD8_benchmark_filtered/LVIKHCDLNK_HLA-A11:01
# 	 0 peptides out of 714 were not betweem 8 and 15 AA.
# Processing ../data/raw/pHLA_binding/CD8_benchmark_filtered/AMAGSPVFL_HLA-A02:01
# 	 0 peptides out of 3430 were not betweem 8 and 15 AA.
# Processing ../data/raw/pHLA_binding/CD8_benchmark_filtered/LYPDAPPLRL_HLA-A24:02
# 	 0 peptides out of 9016 were not betweem 8 and 15 AA.
# Processing ../data/raw/pHLA_binding/CD8_benchmark_filtered/TLLNNCTRV_HLA-A02:01
# 	 0 peptides out of 3633 were not betweem 8 and 15 AA.
# Processing ../data/raw/pHLA_binding/CD8_benchmark_filtered/SMYRVFEVGV_HLA-A02:01
# 	 0 peptides out of 4249 were not betweem 8 and 15 AA.
# Processing ../data/raw/pHLA_binding/CD8_benchmark_filtered/TYGPVFMSL_HLA-A24:02
# 	 0 peptides out of 2576 were not betweem 8 and 15 AA.
# Processing ../data/raw/pHLA_binding/CD8_benchmark_filtered/VTEHDTLL_HLA-A01:01
# 	 0 peptides out of 2961 were not betweem 8 and 15 AA.
# Processing ../data/raw/pHLA_binding/CD8_benchmark_filtered/ELKRKMMYM_HLA-B08:01
# 	 0 peptides out of 3367 were not betweem 8 and 15 AA.
# Processing ../data/raw/pHLA_binding/CD8_benchmark_filtered/ETDENRAKV_HLA-A01:01
# 	 0 peptides out of 23891 were not betweem 8 and 15 AA.
# Processing ../data/raw/pHLA_binding/CD8_benchmark_filtered/LIVDAVLQL_HLA-A02:01
# 	 0 peptides out of 3402 were not betweem 8 and 15 AA.
# Processing ../data/raw/pHLA_binding/CD8_benchmark_filtered/VVNKIRGTFK_HLA-A11:01
# 	 0 peptides out of 3710 were not betweem 8 and 15 AA.
# ...
# Processing ../data/raw/pHLA_binding/CD8_benchmark_filtered/TFILTVVHK_HLA-A11:01
# 	 0 peptides out of 420 were not betweem 8 and 15 AA.
# Processing ../data/raw/pHLA_binding/CD8_benchmark_filtered/FLPDLNANA_HLA-A02:01
# 	 0 peptides out of 5229 were not betweem 8 and 15 AA.
# Processing ../data/raw/pHLA_binding/CD8_benchmark_filtered/FTNHFLVEL_HLA-A02:01
# 	 0 peptides out of 4396 were not betweem 8 and 15 AA.
# Processing ../data/raw/pHLA_binding/CD8_benchmark_filtered/AIATFAAPV_HLA-A02:01
# 	 0 peptides out of 1043 were not betweem 8 and 15 AA.
# Processing ../data/raw/pHLA_binding/CD8_benchmark_filtered/VLCLRPVGA_HLA-A02:01
# 	 0 peptides out of 1008 were not betweem 8 and 15 AA.
# Processing ../data/raw/pHLA_binding/CD8_benchmark_filtered/QLLDGFMITL_HLA-A02:01
# 	 0 peptides out of 5341 were not betweem 8 and 15 AA.
# Processing ../data/raw/pHLA_binding/CD8_benchmark_filtered/LLNGWRWRL_HLA-A02:01
# 	 0 peptides out of 350 were not betweem 8 and 15 AA.
# Processing ../data/raw/pHLA_binding/CD8_benchmark_filtered/YSEHPTFTSQY_HLA-A01:01
# 	 0 peptides out of 3857 were not betweem 8 and 15 AA.
# Processing ../data/raw/pHLA_binding/CD8_benchmark_filtered/YLDELIKNT_HLA-A02:01
# 	 0 peptides out of 10108 were not betweem 8 and 15 AA.
# Processing ../data/raw/pHLA_binding/CD8_benchmark_filtered/ALTAVAEEV_HLA-A02:01
# 	 0 peptides out of 6783 were not betweem 8 and 15 AA.
# Processing ../data/raw/pHLA_binding/CD8_benchmark_filtered/ALFHEVAKL_HLA-A02:01
# 	 0 peptides out of 5705 were not betweem 8 and 15 AA.
# Processing ../data/raw/pHLA_binding/CD8_benchmark_filtered/KLGPGEEQV_HLA-A02:01
# 	 0 peptides out of 1477 were not betweem 8 and 15 AA.
# Processing ../data/raw/pHLA_binding/CD8_benchmark_filtered/WFDISYTIYK_HLA-A11:01
# 	 0 peptides out of 1092 were not betweem 8 and 15 AA.
# Processing ../data/raw/pHLA_binding/CD8_benchmark_filtered/GLAEYAAVK_HLA-A11:01
# 	 0 peptides out of 441 were not betweem 8 and 15 AA.
# Processing ../data/raw/pHLA_binding/CD8_benchmark_filtered/SLLLLPVSV_HLA-A02:01
# 	 0 peptides out of 33957 were not betweem 8 and 15 AA.
# Processing ../data/raw/pHLA_binding/CD8_benchmark_filtered/FPNVKDLNL_HLA-B07:02
# 	 0 peptides out of 5075 were not betweem 8 and 15 AA.
# Processing ../data/raw/pHLA_binding/CD8_benchmark_filtered/HSKKKCDEV_HLA-B08:01
# 	 0 peptides out of 21014 were not betweem 8 and 15 AA.
# Processing ../data/raw/pHLA_binding/CD8_benchmark_filtered/SEMKEAFHGL_HLA-B40:01
# 	 0 peptides out of 23807 were not betweem 8 and 15 AA.
# Processing ../data/raw/pHLA_binding/CD8_benchmark_filtered/MPTNKKINM_HLA-B07:02
# 	 0 peptides out of 1274 were not betweem 8 and 15 AA.
# Processing ../data/raw/pHLA_binding/CD8_benchmark_filtered/RLRPGGKKK_HLA-A30:01
# 	 0 peptides out of 3430 were not betweem 8 and 15 AA.
# Processing ../data/raw/pHLA_binding/CD8_benchmark_filtered/CAFAAETGVAL_HLA-C03:03
# 	 0 peptides out of 11809 were not betweem 8 and 15 AA.
# Processing ../data/raw/pHLA_binding/CD8_benchmark_filtered/DVILPIGTR_HLA-A33:01
# 	 0 peptides out of 23807 were not betweem 8 and 15 AA.
# Processing ../data/raw/pHLA_binding/CD8_benchmark_filtered/STAPPVHNV_HLA-A02:01
# 	 0 peptides out of 8715 were not betweem 8 and 15 AA.
# Processing ../data/raw/pHLA_binding/CD8_benchmark_filtered/SLQQEITLL_HLA-A02:01
# 	 0 peptides out of 2688 were not betweem 8 and 15 AA.
# Processing ../data/raw/pHLA_binding/CD8_benchmark_filtered/RPHERNGFTVL_HLA-B07:02
# 	 0 peptides out of 3857 were not betweem 8 and 15 AA.
# Processing ../data/raw/pHLA_binding/CD8_benchmark_filtered/FLNDLLSVM_HLA-A02:01
# 	 0 peptides out of 14910 were not betweem 8 and 15 AA.
# Processing ../data/raw/pHLA_binding/CD8_benchmark_filtered/AIMDKKIIL_HLA-A02:01
# 	 0 peptides out of 315 were not betweem 8 and 15 AA.
# Processing ../data/raw/pHLA_binding/CD8_benchmark_filtered/AMAGASTSA_HLA-A02:01
# 	 0 peptides out of 3857 were not betweem 8 and 15 AA.
# Processing ../data/raw/pHLA_binding/CD8_benchmark_filtered/RVKARMLTI_HLA-B08:01
# 	 0 peptides out of 20433 were not betweem 8 and 15 AA.
# Processing ../data/raw/pHLA_binding/CD8_benchmark_filtered/TLGQHLPTL_HLA-A02:01
# 	 0 peptides out of 2401 were not betweem 8 and 15 AA.
# Processing ../data/raw/pHLA_binding/CD8_benchmark_filtered/EVNPPFGDSY_HLA-A25:01
# 	 0 peptides out of 23807 were not betweem 8 and 15 AA.
# Processing ../data/raw/pHLA_binding/CD8_benchmark_filtered/SPLVFDSWL_HLA-B07:02
# 	 0 peptides out of 413 were not betweem 8 and 15 AA.
# Processing ../data/raw/pHLA_binding/CD8_benchmark_filtered/RQYDPVAAL_HLA-A32:01_1
# 	 0 peptides out of 3857 were not betweem 8 and 15 AA.
# Processing ../data/raw/pHLA_binding/CD8_benchmark_filtered/FIFMIAEVV_HLA-A02:01
# 	 0 peptides out of 2513 were not betweem 8 and 15 AA.
# Processing ../data/raw/pHLA_binding/CD8_benchmark_filtered/KLAQRRVFH_HLA-A03:01
# 	 0 peptides out of 23807 were not betweem 8 and 15 AA.
# Processing ../data/raw/pHLA_binding/CD8_benchmark_filtered/YHLIVDTDSL_HLA-B38:01
# 	 0 peptides out of 3360 were not betweem 8 and 15 AA.
# Processing ../data/raw/pHLA_binding/CD8_benchmark_filtered/YIFLGNLAL_HLA-A02:01
# 	 0 peptides out of 2177 were not betweem 8 and 15 AA.
# Processing ../data/raw/pHLA_binding/CD8_benchmark_filtered/IPSDLERRIL_HLA-B07:02
# 	 0 peptides out of 4025 were not betweem 8 and 15 AA.
# Processing ../data/raw/pHLA_binding/CD8_benchmark_filtered/RMLMIVLLVF_HLA-A02:01
# 	 0 peptides out of 3038 were not betweem 8 and 15 AA.
# Processing ../data/raw/pHLA_binding/CD8_benchmark_filtered/YMSTTIIAA_HLA-A02:01
# 	 0 peptides out of 3948 were not betweem 8 and 15 AA.
# Processing ../data/raw/pHLA_binding/CD8_benchmark_filtered/KTVDLILEL_HLA-A02:01
# 	 0 peptides out of 13531 were not betweem 8 and 15 AA.
# Processing ../data/raw/pHLA_binding/CD8_benchmark_filtered/GLSPTVWLS_HLA-A02:01
# 	 0 peptides out of 2730 were not betweem 8 and 15 AA.
# Processing ../data/raw/pHLA_binding/CD8_benchmark_filtered/TLDYKPLSV_HLA-A02:01
# 	 0 peptides out of 2758 were not betweem 8 and 15 AA.
# Processing ../data/raw/pHLA_binding/CD8_benchmark_filtered/RLIPFAAPPK_HLA-A11:01
# 	 0 peptides out of 1694 were not betweem 8 and 15 AA.
# Processing ../data/raw/pHLA_binding/CD8_benchmark_filtered/NYTPGPGTRF_HLA-A24:02
# 	 0 peptides out of 1365 were not betweem 8 and 15 AA.
# Processing ../data/raw/pHLA_binding/CD8_benchmark_filtered/TVYAWFTFSH_HLA-A03:01
# 	 0 peptides out of 3038 were not betweem 8 and 15 AA.
# Processing ../data/raw/pHLA_binding/CD8_benchmark_filtered/TLKDIVLDL_HLA-A02:01
# 	 0 peptides out of 616 were not betweem 8 and 15 AA.
# Processing ../data/raw/pHLA_binding/CD8_benchmark_filtered/LLLLGSVTV_HLA-A02:01
# 	 0 peptides out of 5327 were not betweem 8 and 15 AA.
# Processing ../data/raw/pHLA_binding/CD8_benchmark_filtered/IVDQCCTSI_HLA-A02:01
# 	 0 peptides out of 686 were not betweem 8 and 15 AA.
# Processing ../data/raw/pHLA_binding/CD8_benchmark_filtered/FLPSDFLPSV_HLA-A02:01
# 	 0 peptides out of 1204 were not betweem 8 and 15 AA.
# Processing ../data/raw/pHLA_binding/CD8_benchmark_filtered/EECDSELEIKRY_HLA-B44:03
# 	 0 peptides out of 1645 were not betweem 8 and 15 AA.
# Processing ../data/raw/pHLA_binding/CD8_benchmark_filtered/KVYYRSLFI_HLA-A02:01
# 	 0 peptides out of 2688 were not betweem 8 and 15 AA.
# Processing ../data/raw/pHLA_binding/CD8_benchmark_filtered/RPYPLIYFLFL_HLA-B51:01
# 	 0 peptides out of 882 were not betweem 8 and 15 AA.
# Processing ../data/raw/pHLA_binding/CD8_benchmark_filtered/LPFDKSTVM_HLA-B35:01
# 	 0 peptides out of 3416 were not betweem 8 and 15 AA.
# Processing ../data/raw/pHLA_binding/CD8_benchmark_filtered/GEIHAVPFGL_HLA-B40:01
# 	 0 peptides out of 23807 were not betweem 8 and 15 AA.
# Processing ../data/raw/pHLA_binding/CD8_benchmark_filtered/FSDLYYLTM_HLA-A01:01
# 	 0 peptides out of 23891 were not betweem 8 and 15 AA.
# Processing ../data/raw/pHLA_binding/CD8_benchmark_filtered/NLATYMNSI_HLA-A02:01
# 	 0 peptides out of 17815 were not betweem 8 and 15 AA.
# Processing ../data/raw/pHLA_binding/CD8_benchmark_filtered/SLNYSGVKEL_HLA-A02:01
# 	 0 peptides out of 2513 were not betweem 8 and 15 AA.
# Processing ../data/raw/pHLA_binding/CD8_benchmark_filtered/RPAEPVPLQL_HLA-B07:02
# 	 0 peptides out of 280 were not betweem 8 and 15 AA.
# Processing ../data/raw/pHLA_binding/CD8_benchmark_filtered/WILGFVFTL_HLA-A02:01
# 	 0 peptides out of 1694 were not betweem 8 and 15 AA.
# Processing ../data/raw/pHLA_binding/CD8_benchmark_filtered/HAVPFGLVSM_HLA-B35:03
# 	 0 peptides out of 23807 were not betweem 8 and 15 AA.
# Processing ../data/raw/pHLA_binding/CD8_benchmark_filtered/FLFVEALFQ_HLA-A29:02
# 	 0 peptides out of 2709 were not betweem 8 and 15 AA.
# Processing ../data/raw/pHLA_binding/CD8_benchmark_filtered/ALVRCIPTL_HLA-A02:01
# 	 0 peptides out of 3738 were not betweem 8 and 15 AA.
# Processing ../data/raw/pHLA_binding/CD8_benchmark_filtered/VLYSYILFL_HLA-A02:01
# 	 0 peptides out of 784 were not betweem 8 and 15 AA.
# Processing ../data/raw/pHLA_binding/CD8_benchmark_filtered/EYTNIPISL_HLA-A24:02
# 	 0 peptides out of 2401 were not betweem 8 and 15 AA.
# Processing ../data/raw/pHLA_binding/CD8_benchmark_filtered/AVLLHEESM_HLA-B35:01
# 	 0 peptides out of 6496 were not betweem 8 and 15 AA.
# Processing ../data/raw/pHLA_binding/CD8_benchmark_filtered/HDIILECV_HLA-B40:02
# 	 0 peptides out of 1036 were not betweem 8 and 15 AA.
# Processing ../data/raw/pHLA_binding/CD8_benchmark_filtered/ELMTLATWV_HLA-A02:01
# 	 0 peptides out of 1225 were not betweem 8 and 15 AA.
# Processing ../data/raw/pHLA_binding/CD8_benchmark_filtered/MTTEDMLSVW_HLA-B58:01
# 	 0 peptides out of 23674 were not betweem 8 and 15 AA.
# Processing ../data/raw/pHLA_binding/CD8_benchmark_filtered/LITGRLQSL_HLA-A02:01
# 	 0 peptides out of 8715 were not betweem 8 and 15 AA.
# Processing ../data/raw/pHLA_binding/CD8_benchmark_filtered/TMIKTAVAVV_HLA-A02:01
# 	 0 peptides out of 1043 were not betweem 8 and 15 AA.
# Processing ../data/raw/pHLA_binding/CD8_benchmark_filtered/SLAVVSTQL_HLA-A02:01
# 	 0 peptides out of 4655 were not betweem 8 and 15 AA.
# Processing ../data/raw/pHLA_binding/CD8_benchmark_filtered/IPYLDGTFY_HLA-B53:01_1
# 	 0 peptides out of 6706 were not betweem 8 and 15 AA.
# Processing ../data/raw/pHLA_binding/CD8_benchmark_filtered/MPEAMTIVML_HLA-B53:01
# 	 0 peptides out of 23807 were not betweem 8 and 15 AA.
# Processing ../data/raw/pHLA_binding/CD8_benchmark_filtered/LMNGQQIFL_HLA-A02:01
# 	 0 peptides out of 3857 were not betweem 8 and 15 AA.
# Processing ../data/raw/pHLA_binding/CD8_benchmark_filtered/SVVRRAFPH_HLA-A11:01
# 	 0 peptides out of 5831 were not betweem 8 and 15 AA.
# Processing ../data/raw/pHLA_binding/CD8_benchmark_filtered/AVEPGKNPK_HLA-A11:01
# 	 0 peptides out of 23674 were not betweem 8 and 15 AA.
# Processing ../data/raw/pHLA_binding/CD8_benchmark_filtered/FIPENQRTV_HLA-A02:01
# 	 0 peptides out of 2688 were not betweem 8 and 15 AA.
# Processing ../data/raw/pHLA_binding/CD8_benchmark_filtered/TLLTIDGGI_HLA-A02:01
# 	 0 peptides out of 4690 were not betweem 8 and 15 AA.
# Processing ../data/raw/pHLA_binding/CD8_benchmark_filtered/EYVLLLFLL_HLA-A24:02
# 	 0 peptides out of 21000 were not betweem 8 and 15 AA.
# Processing ../data/raw/pHLA_binding/CD8_benchmark_filtered/RLGPYLEFL_HLA-A02:01
# 	 0 peptides out of 9121 were not betweem 8 and 15 AA.
# Processing ../data/raw/pHLA_binding/CD8_benchmark_filtered/AEVIAPAVQT_HLA-B44:02
# 	 0 peptides out of 20615 were not betweem 8 and 15 AA.
# Processing ../data/raw/pHLA_binding/CD8_benchmark_filtered/QLGAFLTNV_HLA-A02:01
# 	 0 peptides out of 2401 were not betweem 8 and 15 AA.
# Processing ../data/raw/pHLA_binding/CD8_benchmark_filtered/QLSYTELAAK_HLA-A03:01
# 	 0 peptides out of 2709 were not betweem 8 and 15 AA.
# Processing ../data/raw/pHLA_binding/CD8_benchmark_filtered/RPGCDAPAY_HLA-B35:01
# 	 0 peptides out of 3108 were not betweem 8 and 15 AA.
# Processing ../data/raw/pHLA_binding/CD8_benchmark_filtered/SLGLVILLVL_HLA-A02:01
# 	 0 peptides out of 2576 were not betweem 8 and 15 AA.
# Processing ../data/raw/pHLA_binding/CD8_benchmark_filtered/CQTYKWETF_HLA-B08:01
# 	 0 peptides out of 2205 were not betweem 8 and 15 AA.
# Processing ../data/raw/pHLA_binding/CD8_benchmark_filtered/MMIEEYPYV_HLA-A02:01_1
# 	 0 peptides out of 2044 were not betweem 8 and 15 AA.
# Processing ../data/raw/pHLA_binding/CD8_benchmark_filtered/FTDWANKQY_HLA-A30:02
# 	 0 peptides out of 4368 were not betweem 8 and 15 AA.
# Processing ../data/raw/pHLA_binding/CD8_benchmark_filtered/SLLWMNPFV_HLA-A02:01
# 	 0 peptides out of 2086 were not betweem 8 and 15 AA.
# Processing ../data/raw/pHLA_binding/CD8_benchmark_filtered/FVFPTKDVALR_HLA-A68:01
# 	 0 peptides out of 3857 were not betweem 8 and 15 AA.
# Processing ../data/raw/pHLA_binding/CD8_benchmark_filtered/GLMAIAWFI_HLA-A02:01
# 	 0 peptides out of 1596 were not betweem 8 and 15 AA.
# Processing ../data/raw/pHLA_binding/CD8_benchmark_filtered/RLAAGSPSS_HLA-A02:01
# 	 0 peptides out of 1526 were not betweem 8 and 15 AA.
# Processing ../data/raw/pHLA_binding/CD8_benchmark_filtered/GLSPTVWLS_HLA-A02:01_1
# 	 0 peptides out of 2653 were not betweem 8 and 15 AA.
# Processing ../data/raw/pHLA_binding/CD8_benchmark_filtered/HLAAQGMAY_HLA-B46:01
# 	 0 peptides out of 6538 were not betweem 8 and 15 AA.
# Processing ../data/raw/pHLA_binding/CD8_benchmark_filtered/TAGSLQGQW_HLA-B58:01
# 	 0 peptides out of 630 were not betweem 8 and 15 AA.
# Processing ../data/raw/pHLA_binding/CD8_benchmark_filtered/EYVHARWAAF_HLA-A24:02
# 	 0 peptides out of 8575 were not betweem 8 and 15 AA.
# Processing ../data/raw/pHLA_binding/CD8_benchmark_filtered/GVLDAVWRV_HLA-A02:01
# 	 0 peptides out of 1519 were not betweem 8 and 15 AA.
# Processing ../data/raw/pHLA_binding/CD8_benchmark_filtered/RPALLVSFIF_HLA-B07:02
# 	 0 peptides out of 23891 were not betweem 8 and 15 AA.
# Processing ../data/raw/pHLA_binding/CD8_benchmark_filtered/TFTNMEAQLI_HLA-A24:02
# 	 0 peptides out of 23667 were not betweem 8 and 15 AA.
# Processing ../data/raw/pHLA_binding/CD8_benchmark_filtered/HISALKRRY_HLA-A29:02
# 	 0 peptides out of 1078 were not betweem 8 and 15 AA.
# Processing ../data/raw/pHLA_binding/CD8_benchmark_filtered/ALAYGIDKV_HLA-A02:01
# 	 0 peptides out of 4550 were not betweem 8 and 15 AA.
# Processing ../data/raw/pHLA_binding/CD8_benchmark_filtered/GPCKVPAQMAV_HLA-B07:02
# 	 0 peptides out of 23891 were not betweem 8 and 15 AA.
# Processing ../data/raw/pHLA_binding/CD8_benchmark_filtered/NPTITVVTSV_HLA-B51:01
# 	 0 peptides out of 2709 were not betweem 8 and 15 AA.
# Processing ../data/raw/pHLA_binding/CD8_benchmark_filtered/IMGGELPTA_HLA-A02:01
# 	 0 peptides out of 21077 were not betweem 8 and 15 AA.
# Processing ../data/raw/pHLA_binding/CD8_benchmark_filtered/LMLWASSSI_HLA-A02:01
# 	 0 peptides out of 2695 were not betweem 8 and 15 AA.
# Processing ../data/raw/pHLA_binding/CD8_benchmark_filtered/MINAYLDKL_HLA-A02:01
# 	 0 peptides out of 4158 were not betweem 8 and 15 AA.
# Processing ../data/raw/pHLA_binding/CD8_benchmark_filtered/RRSGAAGAAVE_HLA-B27:05
# 	 0 peptides out of 3416 were not betweem 8 and 15 AA.
# Processing ../data/raw/pHLA_binding/CD8_benchmark_filtered/LLDQLIEEV_HLA-A02:01
# 	 0 peptides out of 1953 were not betweem 8 and 15 AA.
# Processing ../data/raw/pHLA_binding/CD8_benchmark_filtered/LLDKRQFELY_HLA-A01:01
# 	 0 peptides out of 23807 were not betweem 8 and 15 AA.
# Processing ../data/raw/pHLA_binding/CD8_benchmark_filtered/SPKGISRMSM_HLA-B07:02
# 	 0 peptides out of 23807 were not betweem 8 and 15 AA.
# Processing ../data/raw/pHLA_binding/CD8_benchmark_filtered/SLILIGITTL_HLA-A02:01
# 	 0 peptides out of 1449 were not betweem 8 and 15 AA.
# Processing ../data/raw/pHLA_binding/CD8_benchmark_filtered/AIMDKTIIL_HLA-A02:01
# 	 0 peptides out of 1505 were not betweem 8 and 15 AA.
# Processing ../data/raw/pHLA_binding/CD8_benchmark_filtered/ALVGAIPSI_HLA-A02:01
# 	 0 peptides out of 13930 were not betweem 8 and 15 AA.
# Processing ../data/raw/pHLA_binding/CD8_benchmark_filtered/SSNIMSESY_HLA-A30:02
# 	 0 peptides out of 4389 were not betweem 8 and 15 AA.
# Processing ../data/raw/pHLA_binding/CD8_benchmark_filtered/WAAVTLLLL_HLA-B51:01
# 	 0 peptides out of 847 were not betweem 8 and 15 AA.
# Processing ../data/raw/pHLA_binding/CD8_benchmark_filtered/LLCPSGHVV_HLA-A02:01
# 	 0 peptides out of 21000 were not betweem 8 and 15 AA.
# Processing ../data/raw/pHLA_binding/CD8_benchmark_filtered/IYAGSLSAL_HLA-B07:02
# 	 0 peptides out of 2205 were not betweem 8 and 15 AA.

# %%
test_set_df.peptide.str.len().value_counts()
# Out:
# peptide
# 8     1686889
# 9     1685112
# 10    1683467
# 11    1681756
# 12    1680045
# 13    1678335
# 14    1676626
# Name: count, dtype: int64
